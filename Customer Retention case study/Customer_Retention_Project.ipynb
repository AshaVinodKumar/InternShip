# %% [markdown]
# # Problem Statement:
#
# # E-retail factors for customer activation and retention:
#
# # A case study from Indian e-commerce customers
#
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention.
#
# Five major factors that contributed to the success of an e-commerce store have been identified as:
#
# service quality
#
# system quality
#
# information quality
#
# trust
#
# net benefit.
#
#
# The research furthermore investigated the factors that influence the online customers repeat purchase intention. The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively. The data is collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for customer satisfaction.

# %%
# Importing necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# Loading the dataset
df=pd.read_excel('customer_retention_dataset.xlsx')
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %% [markdown]
# There are 71 Columns. However renaming the columns for easier understanding is required as the column names are in the form of questions and bit lengthy. So lets give them a short and meaningful names.

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df=df.rename(columns={'1Gender of respondent':'Gender','2 How old are you? ':'Age','3 Which city do you shop online from?':'City','4 What is the Pin Code of where you shop online from?':'Pin_Code','5 Since How Long You are Shopping Online ?':'Years_Of_Shopping','6 How many times you have made an online purchase in the past 1 year?':'Past_1Year_Purchase','7 How do you access the internet while shopping on-line?':'Internet_Type','8 Which device do you use to access the online shopping?':'Device_Type','9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ':'Device_Screen_size', '10 What is the operating system (OS) of your device?\t\t\t\t                                          ':'OS_of_Device','11 What browser do you run on your device to access the website?\t\t\t                                                          ':'Browser_Used', '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ':'Channel_Used', '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ':'First_visit_to_Store', '14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ':'Browsing_Time','15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ':'Payment_Option', '16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ':'Window_Shopping', '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ':'Reason_for_Window_Shopping','18 The content on the website must be easy to read and understand':'Product_Description','19 Information on similar product to the one highlighted  is important for product comparison':'Similar_Product','20 Complete information on listed seller and product being offered is important for purchase decision.':'seller_information','21 All relevant information on listed products must be stated clearly':'Clear_Description_Of_Product','22 Ease of navigation in website':'Navigation_Ease', '23 Loading and processing speed':'Processing_Speed','24 User friendly Interface of the website':'User_Friendly','25 Convenient Payment methods':'Payment_Methods','26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time':'Trust_On_Retailer','27 Empathy (readiness to assist with queries) towards the customers':'Empathy','28 Being able to guarantee the privacy of the customer':'Privacy_Guarantee', '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)':'Responsiveness',
              '30 Online shopping gives monetary benefit and discounts':'Online_Benefits','31 Enjoyment is derived from shopping online':'Enjoyment',
              '32 Shopping online is convenient and flexible':'Convenient', '33 Return and replacement policy of the e-tailer is important for purchase decision':'Replacement_Replacments',
             '34 Gaining access to loyalty programs is a benefit of shopping online':'Loyalty_Programs', '35 Displaying quality Information on the website improves satisfaction of customers':'Quality_Information',
              '36 User derive satisfaction while shopping on a good quality website or application':'Website_Quality',
              '37 Net Benefit derived from shopping online can lead to users satisfaction':'Shopping_Benefit',
              '38 User satisfaction cannot exist without trust':'User_Satisfaction', '39 Offering a wide variety of listed product in several category':'Product_Variety',
              '40 Provision of complete and relevant product information':'Relevant_Info','41 Monetary savings':'Savings',
              '42 The Convenience of patronizing the online retailer':'Convenience',
              '43 Shopping on the website gives you the sense of adventure':'Adventure_Sense', '44 Shopping on your preferred e-tailer enhances your social status':'Social_Status',
              '45 You feel gratification shopping on your favorite e-tailer':'Gratification', '46 Shopping on the website helps you fulfill certain roles':'Roles_Fullfillment',
              '47 Getting value for money spent':'Value_For_Money',
              'From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ':'retailers',
              'Easy to use website or application':'Use_Ease', 'Visual appealing web-page layout':'Layout', 'Wild variety of product on offer':'Product_On_Offer',
              'Complete, relevant description information of products':'Information_Of_Products', 'Fast loading website speed of website and application':'Loading_Speed',
              'Reliability of the website or application':'Website_Reliability', 'Quickness to complete purchase':'Quick_Purchase',
              'Availability of several payment options':'Payment_Availability', 'Speedy order delivery ':'Delivery_Speed','Privacy of customers’ information':'Customer_Privacy',
              'Security of customer financial information':'Financial_Security', 'Perceived Trustworthiness':'Trustworthiness',
              'Presence of online assistance through multi-channel':'Online_Assistance',
              'Longer time to get logged in (promotion, sales period)':'Promotion_Period', 'Longer time in displaying graphics and photos (promotion, sales period)':'Graphics_Load_Time',
              'Late declaration of price (promotion, sales period)':'price_declaration', 'Longer page loading time (promotion, sales period)':'page_loading_time',
              'Limited mode of payment on most products (promotion, sales period)':'Limited_Payment_Mode',
              'Longer delivery period':'Delivery_Period', 'Change in website/Application design':'Design_Change', 
              'Frequent disruption when moving from one page to another':'Disruption_Of_page', 'Website is as efficient as before':'Efficiency_Of_website',
       'Which of the Indian online retailer would you recommend to a friend?':'Recommandations_Of_Retailers'})

# %%
df.head()
# Out:
#    Gender          Age           City  Pin_Code Years_Of_Shopping  \
# 0    Male  31-40 years          Delhi    110009     Above 4 years
# 1  Female  21-30 years          Delhi    110030     Above 4 years
# 2  Female  21-30 years  Greater Noida    201308         3-4 years
# 3    Male  21-30 years        Karnal     132001         3-4 years
# 4  Female  21-30 years     Bangalore     530068         2-3 years
#
#   Past_1Year_Purchase    Internet_Type Device_Type Device_Screen_size  \
# 0         31-40 times          Dial-up     Desktop             Others
# 1  41 times and above            Wi-Fi  Smartphone         4.7 inches
# 2  41 times and above  Mobile Internet  Smartphone         5.5 inches
# 3  Less than 10 times  Mobile Internet  Smartphone         5.5 inches
# 4         11-20 times            Wi-Fi  Smartphone         4.7 inches
#
#             OS_of_Device  ...         Promotion_Period  \
# 0  Window/windows Mobile  ...                Amazon.in
# ...

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'City', 'Pin_Code', 'Years_Of_Shopping',
#        'Past_1Year_Purchase', 'Internet_Type', 'Device_Type',
#        'Device_Screen_size', 'OS_of_Device', 'Browser_Used', 'Channel_Used',
#        'First_visit_to_Store', 'Browsing_Time', 'Payment_Option',
#        'Window_Shopping', 'Reason_for_Window_Shopping', 'Product_Description',
#        'Similar_Product', 'seller_information', 'Clear_Description_Of_Product',
#        'Navigation_Ease', 'Processing_Speed', 'User_Friendly',
#        'Payment_Methods', 'Trust_On_Retailer', 'Empathy', 'Privacy_Guarantee',
#        'Responsiveness', 'Online_Benefits', 'Enjoyment', 'Convenient',
#        'Replacement_Replacments', 'Loyalty_Programs', 'Quality_Information',
#        'Website_Quality', 'Shopping_Benefit', 'User_Satisfaction',
#        'Product_Variety', 'Relevant_Info', 'Savings', 'Convenience',
#        'Adventure_Sense', 'Social_Status', 'Gratification',
# ...

# %% [markdown]
# As seen from above now the column names looks clean and organised.

# %%
#Checking for data shape
df.shape
# Out:
# (269, 71)

# %% [markdown]
# Rows of 269 and 71 column dataset.

# %%
#  Checking for data type
df.dtypes
# Out:
# Gender                          object
# Age                             object
# City                            object
# Pin_Code                         int64
# Years_Of_Shopping               object
# Past_1Year_Purchase             object
# Internet_Type                   object
# Device_Type                     object
# Device_Screen_size              object
# OS_of_Device                    object
# Browser_Used                    object
# Channel_Used                    object
# First_visit_to_Store            object
# Browsing_Time                   object
# Payment_Option                  object
# Window_Shopping                 object
# Reason_for_Window_Shopping      object
# Product_Description             object
# Similar_Product                 object
# seller_information              object
# Clear_Description_Of_Product    object
# Navigation_Ease                 object
# Processing_Speed                object
# User_Friendly                   object
# ...

# %% [markdown]
# With only one integer type the rest of the columns are of object type. Label Encoding the object type helps built the predictive model.

# %%
# Checking for null values
df.isnull().sum()
# Out:
# Gender                          0
# Age                             0
# City                            0
# Pin_Code                        0
# Years_Of_Shopping               0
# Past_1Year_Purchase             0
# Internet_Type                   0
# Device_Type                     0
# Device_Screen_size              0
# OS_of_Device                    0
# Browser_Used                    0
# Channel_Used                    0
# First_visit_to_Store            0
# Browsing_Time                   0
# Payment_Option                  0
# Window_Shopping                 0
# Reason_for_Window_Shopping      0
# Product_Description             0
# Similar_Product                 0
# seller_information              0
# Clear_Description_Of_Product    0
# Navigation_Ease                 0
# Processing_Speed                0
# User_Friendly                   0
# Payment_Methods                 0
# Trust_On_Retailer               0
# Empathy                         0
# ...

# %% [markdown]
# Since all the nulls indicate zero there are no missing values in the dataset which is ideal for building of a predictive model.

# %% [markdown]
# # Data Visualization

# %%
# Taking from the first column lets visualize the data set
#Checking for values counts of Gender
df['Gender'].value_counts()
# Out:
# Female    181
# Male       88
# Name: Gender, dtype: int64

# %%
#Plotting the same
plt.figure(figsize=[6,6])
df['Gender'].value_counts().plot.pie(autopct = '%.1f%%')
# Out:
# <AxesSubplot:ylabel='Gender'>

# %% [markdown]
# The Female ratio is more:67.3%
# The male ratio is less:32.7%

# %%
#Age Vs Gender
print(df['Age'].value_counts())
plt.figure(figsize=(10,4))
sns.countplot(x=df['Age'],hue = df['Gender'])
plt.title('Age Vs Gender')
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: Age, dtype: int64
# Text(0.5, 1.0, 'Age Vs Gender')

# %% [markdown]
# The Ratio of female on all age groups holds the upper hand.

# %%
print(df['City'].value_counts())
plt.figure(figsize=(20,10))
sns.countplot(x=df['City'],hue=df['Age'])
plt.title('City')
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Ghaziabad        18
# Solan            18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: City, dtype: int64
# Text(0.5, 1.0, 'City')

# %% [markdown]
# THe cities like BAngalore, Greater Noida, Nodia and karnal shops the most online. and one interseting observation is that people ages above 51yrs shops the most in Gurgaon.

# %%
print(df['Pin_Code'].value_counts())
plt.figure(figsize=(30,20))
sns.countplot(x=df['Pin_Code'],hue=df['Age'])
plt.title('Pin_Code')
# Out:
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 173229     9
# 173212     9
# 250001     9
# 122018     8
# 560037     8
# 132036     8
# 560010     8
# 110011     7
# 110008     7
# 201306     7
# 110014     6
# 110018     6
# 201008     5
# 201009     5
# 201305     5
# 201312     5
# 244001     5
# 530068     5
# 201005     4
# 110009     4
# 110042     4
# 110039     4
# 110030     4
# 201304     4
# 122009     4
# 201303     4
# 560018     4
# 201001     4
# 560003     4
# 560002     4
# 560013     3
# 203001     2
# 203207     1
# 560001     1
# 203202     1
# Name: Pin_Code, dtype: int64
# Text(0.5, 1.0, 'Pin_Code')

# %% [markdown]
# The pincode with 201308 i.e, Noida city Shops the most.

# %%
df['Years_Of_Shopping'].value_counts()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: Years_Of_Shopping, dtype: int64

# %%
plt.figure(figsize=[8,8])
df['Years_Of_Shopping'].value_counts().plot.pie(autopct = '%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Years_Of_Shopping'>

# %% [markdown]
# Most of the customers are shopping online for more than 4 years, followed by 4 to 3 years, 3 to 2 years, 1 to 2 years and less than 1 year.

# %%
print(df['Past_1Year_Purchase'].value_counts())
plt.figure(figsize=(40,25))
sns.countplot(x=df['Past_1Year_Purchase'],hue=df['Gender'])
plt.title('Past_1Year_Purchase')
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: Past_1Year_Purchase, dtype: int64
# Text(0.5, 1.0, 'Past_1Year_Purchase')

# %% [markdown]
# Females who shopped less than 10 times are more.

# %%
df['Internet_Type'].value_counts()
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: Internet_Type, dtype: int64

# %%
plt.figure(figsize=[8,8])
df['Internet_Type'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Internet_Type'>

# %% [markdown]
# 53% of the users use mobile internet and only 1.5% of users use dail up.

# %%
# Checking for the value count of the devices
df['Device_Type'].value_counts()
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: Device_Type, dtype: int64

# %%
plt.figure(figsize=[8,8])
df['Device_Type'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Device_Type'>

# %% [markdown]
# Majority og the population uses smart phone for their shopping needs as it is very handy and the least percentage of population uses tablet.

# %%
# Checking for the value counts of the Device_Screen_size used by the customers:
plt.figure(figsize=[6,6])
df['Device_Screen_size'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Device_Screen_size'>

# %% [markdown]
# Looking at the graph 5.5 inches is known data to be used more. by=ut the % of others are even more so could be assumed the bigger screen the better.

# %%
# Checking for the value count of the devices
df['OS_of_Device'].value_counts()
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: OS_of_Device, dtype: int64

# %%
plt.figure(figsize=[6,6])
df['OS_of_Device'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='OS_of_Device'>

# %% [markdown]
# We can see The windows user are more than Android and IOS more so because windows are user friendly.

# %%
# Checking for the value count of the Browser_Used
df['Browser_Used'].value_counts()
# Out:
# Google chrome      216
# Safari              40
# Opera                8
# Mozilla Firefox      5
# Name: Browser_Used, dtype: int64

# %%
plt.figure(figsize=[6,6])
df['Browser_Used'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Browser_Used'>

# %% [markdown]
# Google Chrome bangs the highest assuming to be more user friendly.

# %%
# Checking for the value count of the Channel_Used
df['Channel_Used'].value_counts()
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: Channel_Used, dtype: int64

# %%
plt.figure(figsize=[6,6])
df['Channel_Used'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Channel_Used'>

# %% [markdown]
# More than 85% of users use search engine to land on their favourite website.

# %%
# Checking for the value count of the Channel_Used
df['First_visit_to_Store'].value_counts()
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: First_visit_to_Store, dtype: int64

# %%
plt.figure(figsize=[6,6])
df['First_visit_to_Store'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='First_visit_to_Store'>

# %% [markdown]
# People visiting stores and people browsing the online site are in equal ratio before their purchase.which ia approximately 32%. Also getting influnced by social media is counted least.

# %%
# Checking for the value count of the Channel_Used
df['Browsing_Time'].value_counts()
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: Browsing_Time, dtype: int64

# %%
# Checking for the value counts of Browsing_Time by the customers:
plt.figure(figsize=[6,6])
df['Browsing_Time'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Browsing_Time'>

# %% [markdown]
# Maximum customers explore the e-store for more than 15 minutes before making any purchase.

# %%
# Checking for Gender specific browsing time.
print(df['Browsing_Time'].value_counts())
plt.figure(figsize=(40,25))
sns.countplot(x=df['Browsing_Time'],hue=df['Gender'])
plt.title('Browsing_Time')
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: Browsing_Time, dtype: int64
# Text(0.5, 1.0, 'Browsing_Time')

# %% [markdown]
# Female customers spend more time than the male customers.

# %%
# Checking for the count of the payment options
plt.figure(figsize=[6,6])
df['Payment_Option'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Payment_Option'>

# %% [markdown]
# Credit/Debit card payment option is most popular payment method among the customers to shop online.

# %%
# PAyment methods vs age
print(df['Payment_Option'].value_counts())
plt.figure(figsize=(40,25))
sns.countplot(x=df['Payment_Option'],hue=df['Age'])
plt.title('Payment_Option')
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: Payment_Option, dtype: int64
# Text(0.5, 1.0, 'Payment_Option')

# %% [markdown]
# People in the age group of 21-30years make the the most payments from credit/debit cards , 31-40 years use most of cash on delivery and less than 20 years use the least of e- wallet.

# %%
# Checking for the shopping cart abandon by male and female customers
plt.figure(figsize=[8,6])
sns.countplot(x=df['Window_Shopping'], hue=df['Gender'], data=df)
plt.xlabel('Window_Shopping')
plt.ylabel('Counts')
plt.title('Gender wise cart abandon')
plt.show()

# %% [markdown]
# Female customers Abandon the carts more frequently than male customers.

# %%
# why customers abandon shopping cart
# Checking for the value counts
plt.figure(figsize=[6,6])
df['Reason_for_Window_Shopping'].value_counts().plot.pie(autopct = '%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Reason_for_Window_Shopping'>

# %% [markdown]
# THe carts are usualy abanded because the customers find better alternative offer anf only few abandon for not having preffered payment option. next major reason is that the promo codes are not applicable.

# %%
# customers think content on the website must be easy to read and understand.
plt.figure(figsize=[6,6])
df['Product_Description'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Product_Description'>

# %% [markdown]
# 60% of population strongly agree the content of website has to be easy to understand and 30% do agree for the same. so in total approx 90% of them agree the website should have a neat description.

# %%
# Customers checking for similar products
# Checking for the value counts
plt.figure(figsize=[6,6])
df['Similar_Product'].value_counts().plot.pie(autopct = '%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Similar_Product'>

# %% [markdown]
# Here also approx 78% of people look for similar looking products to grab them if are are at a good deal.

# %%
#Checking if information on the listed seller and product helps customer for purchase decision
plt.figure(figsize=[6,6])
df['seller_information'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='seller_information'>

# %% [markdown]
# Approximately 70% of people check for complete information of the seller while making a decision to purchase an item. It only shows the trust issues customers might have.

# %%
#All relevant information on listed products must be stated clearly
plt.figure(figsize=[6,6])
df['Clear_Description_Of_Product'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Clear_Description_Of_Product'>

# %% [markdown]
# 90% of people agree on getting all relevant information of the product must be listed clearly to make a purchase.

# %%
#Ease of navigation in website
plt.figure(figsize=[6,6])
df['Navigation_Ease'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Navigation_Ease'>

# %% [markdown]
# 92% people agree on having a smooth navigation through the website to make their purchases.

# %%
#Processing speed of the product
plt.figure(figsize=[6,6])
df['Processing_Speed'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Processing_Speed'>

# %% [markdown]
# 83% People prefers having a good processing speed is a need for their e shopping.

# %%
#User FRiendliness of the website
plt.figure(figsize=[6,6])
df['User_Friendly'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='User_Friendly'>

# %% [markdown]
# 87% people vouch to have a user friendly website.

# %%
#Trust on the retailer
plt.figure(figsize=[6,6])
df['Trust_On_Retailer'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Trust_On_Retailer'>

# %% [markdown]
# 85% people spend on the trust they have on their retailer.

# %%
#guarantee the privacy of the customer
plt.figure(figsize=[6,6])
df['Privacy_Guarantee'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Privacy_Guarantee'>

# %% [markdown]
# Maximum customers agrees that the online retail stores are being able to guarantee the privacy of the customer.

# %%
# Online shopping gives monetary benefit and discounts
plt.figure(figsize=[6,6])
df['Online_Benefits'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Online_Benefits'>

# %% [markdown]
# Most of the customers agrees that online shopping gives them monetary benefit and discounts

# %%
# Enjoyment is derived from shopping online
plt.figure(figsize=[6,6])
df['Enjoyment'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Enjoyment'>

# %% [markdown]
# 60% of people belive to have an enjoyment shopping online where as the rest of the crowd belives to have enjoyment in other intangable things.

# %%
# Shopping online is convenient and flexible
plt.figure(figsize=[6,6])
df['Convenient'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Convenient'>

# %% [markdown]
# Approx 84% of people belive it is very convenient to shop online may be because it saves fuel, traffic, time, energy and door step delivery.

# %%
#Return and replacement policy of the e-retailer is important for purchase decision
plt.figure(figsize=[6,6])
df['Replacement_Replacments'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Replacement_Replacments'>

# %% [markdown]
# 93% of people shops online belives to make a purchase in e store only when they have a gaurenteed return/replacment policy as many time the picture on product description may be deciving.

# %%
# Gaining access to loyalty programs is a benefit of shopping online
plt.figure(figsize=[6,6])
df['Loyalty_Programs'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Loyalty_Programs'>

# %% [markdown]
# 74% people belive so that having a loyalty program help them save more, build trust as a brand in the market.

# %%
# Displaying quality Information on the website improves satisfaction of customers
plt.figure(figsize=[6,6])
df['Quality_Information'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Quality_Information'>

# %% [markdown]
# 81% belive that displying of the quality information is very important for the price they pay trusting the retailer and not having the feel of the product.

# %%
# User satisfaction cannot exist without trust
plt.figure(figsize=[6,6])
df['User_Satisfaction'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='User_Satisfaction'>

# %% [markdown]
# 90% of the  customers strongly agree that user satisfaction cannot exist without trust.

# %%
# Shopping for saving
plt.figure(figsize=[6,6])
df['Savings'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Savings'>

# %% [markdown]
# 84% people belive the savings are one of the reasons for online shopping.

# %%
# Shopping on your preferred e-tailer enhances your social status
plt.figure(figsize=[6,6])
df['Social_Status'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Social_Status'>

# %% [markdown]
# As seen in graph this is quite indifferent for many people as the status is different for different people.

# %%
# You feel gratification shopping on your favorite e-tailer
plt.figure(figsize=[6,6])
df['Gratification'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Gratification'>

# %% [markdown]
# Most of the users are indifferent that they feel gratification shopping on their favorite e-tailer

# %%
# Shopping on the website helps you fulfill certain roles
plt.figure(figsize=[6,6])
df['Roles_Fullfillment'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Roles_Fullfillment'>

# %% [markdown]
# THis graph also give a mixed opinion on fulfillment of certain roles as roles are different to different people.

# %%
# Getting value for money spent
plt.figure(figsize=[6,6])
df['Value_For_Money'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Value_For_Money'>

# %% [markdown]
# The graph is the indication of the hard earned money well spent, customers prioritise the value for their money.

# %% [markdown]
# # From the following, tick any (or all) of the online retailers you have shopped from.

# %%
plt.figure(figsize=[6,6])
df['retailers'].value_counts().plot.pie(autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='retailers'>

# %% [markdown]
# Since we see that all the sections of the graph highlights amazon, most of the customers use amazon for their e shopping.

# %%
# Easy to use website or application
plt.figure(figsize=[6,6])
df['Use_Ease'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='Use_Ease'>

# %% [markdown]
# Almost all customers says that amazon.in website or application is easy to use followed by flipkart.com and paytm.com.

# %%
# Visual appealing web-page layout
plt.figure(figsize=[6,6])
df['Layout'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='Layout'>

# %% [markdown]
# As per the graph we can say that most of the customers says that amazon.com and flipkart.com have visual appealing web-page layout.

# %%
# Product_On_Offer
plt.figure(figsize=[6,6])
df['Product_On_Offer'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='Product_On_Offer'>

# %% [markdown]
# Amazon tops on the products that are on offer flipkart and myntra.

# %%
# Complete, relevant description information of products
plt.figure(figsize=[6,6])
df['Information_Of_Products'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='Information_Of_Products'>

# %% [markdown]
# Most of the cusotomers says that amazon.in and flipkart.com have complete, relevant description information of products

# %%
# Fast loading website speed of website and application
plt.figure(figsize=[6,6])
df['Loading_Speed'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='Loading_Speed'>

# %% [markdown]
# Most of the customers says that amazon.in and flipkart.com have fast loading website speed of website and application.

# %%
# Quickness to complete purchase
plt.figure(figsize=[6,6])
df['Quick_Purchase'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='Quick_Purchase'>

# %% [markdown]
# The graph shows that amazon.in have quickness to complete purchase.

# %%
# Availability of several payment options
plt.figure(figsize=[6,6])
df['Payment_Availability'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='Payment_Availability'>

# %% [markdown]
# Several payment options are available with amazon.in followed by flipkart.

# %%
# Delivery Speed of the product
plt.figure(figsize=[6,6])
df['Delivery_Speed'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='Delivery_Speed'>

# %% [markdown]
# Amazon has the gaureented and quickest delivery speed followed by flipkart.

# %%
# Privacy of customers’ information
plt.figure(figsize=[6,6])
df['Customer_Privacy'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='Customer_Privacy'>

# %% [markdown]
# Most of the  customers thinks their information is safe on amazon.in.

# %%
# Security of customer financial information
plt.figure(figsize=[6,6])
df['Financial_Security'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='Financial_Security'>

# %% [markdown]
# Most of the customers say amazon.in have perceived trustworthiness.

# %%
#Trustworthiness
plt.figure(figsize=[6,6])
df['Trustworthiness'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='Trustworthiness'>

# %% [markdown]
# Amazon bags the trustworthiness of the customers followed by flipkart and myntra.

# %%
# Online_Assistance to customers
plt.figure(figsize=[6,6])
df['Online_Assistance'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='Online_Assistance'>

# %% [markdown]
# Amazon tops for good online assistance to its customer through the customer care centers followed by flipkart and myntra.

# %%
# Graphics_Load_Time to customers
plt.figure(figsize=[6,6])
df['Graphics_Load_Time'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='Graphics_Load_Time'>

# %% [markdown]
# Amazon tops for the short load time of graphics followed bt myntra and flipkart. the load speed however depends both on the retailer and the internet speed at the customer end.

# %%
# Late declaration of price (promotion, sales period)
plt.figure(figsize=[6,6])
df['price_declaration'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='price_declaration'>

# %% [markdown]
# Late declaration of price is made by myntra.com and paytm.com during the promotion or sales period

# %%
# Longer page loading time (promotion, sales period)
plt.figure(figsize=[6,6])
df['page_loading_time'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='page_loading_time'>

# %% [markdown]
# Paytm.com and Myntra.com have longer page loading time during the promotion and sales period.

# %%
# Limited mode of payment on most products (promotion, sales period)
plt.figure(figsize=[6,6])
df['Limited_Payment_Mode'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='Limited_Payment_Mode'>

# %% [markdown]
# During the promotion and sales period snapdeal.com and amazon.in have limited mode of payment on most products.

# %%
# Longer delivery period
plt.figure(figsize=[6,6])
df['Delivery_Period'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='Delivery_Period'>

# %% [markdown]
# Myntra.com take minimum delivery period. Paytm.com and snapdeal.com take maximum delivery period. May be this is the reason of low popularity of these web-stores among the customers.

# %%
# Frequent disruption when moving from one page to another
plt.figure(figsize=[6,6])
df['Disruption_Of_page'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='Disruption_Of_page'>

# %% [markdown]
# Amazon and Myntra face disruption from moving from one page to another page may be due to high demands of customers login ang browsing traffic.

# %%
# Website is as efficient as before
plt.figure(figsize=[6,6])
df['Efficiency_Of_website'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='Efficiency_Of_website'>

# %% [markdown]
# Most of the customers say that amazon.in and flipkart.com websites are as efficient as before.

# %%
#Which of the Indian online retailer would you recommend to a friend?
plt.figure(figsize=[6,6])
df['Recommandations_Of_Retailers'].value_counts().plot.pie(autopct='%0.1f##')
# Out:
# <AxesSubplot:ylabel='Recommandations_Of_Retailers'>

# %% [markdown]
# - Most of the customers like to recommend amazon.in and flipkart.com to their friend. This shows that most of the customers like to shop from these two web-store.
# - Also the graph shows that Snapdeal.com have only 4.1% recommandations. This shows customers lack of interest in snapdeal.

# %% [markdown]
# # Conclusion:

# %% [markdown]
# From the above case study through the data set provided there are multiple factors that contribute for the customer to shop online than going to stores and for the E-Retailers to retain there customers. The most looked upon factors are as follows:
#
# 1. The Website being User Friendly.
#
#
# 2. Multiple options for Payment(credit/debit cards, cash on delivery, net banking, e -wallet, EMI's etc...,) and at the same time maintaining the strict privacy policy where no user information is breached.
#
#
# 3. Websites running discounts attracts many customers as they belive major savings is done.
#
#
# 4. Another major factor is the ease at finding the product, their clear description, quality assurance, smooth page navigation and many similar listed products.
#
#
# 5. Customers also look for the trust they have in the retailer before they make any purchase.
#
#
# 6. Delivery Speed and processing spped also play its part in making online purchasres.
#
#
# 7. Loyalty Programs for customers acts as an additional support for retailers to retain their customers.
#
# 8. With respect to all the points stated above amazon , flipkart and myntra have gained the most popularity for all the services they provide which a customer looks for.
