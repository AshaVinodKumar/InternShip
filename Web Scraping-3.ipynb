# %%
# !pip install selenium

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings. filterwarnings("ignore")

# %%
# Q1 Part A

# %%
driver=webdriver.Chrome(r"C:\Users\cjash\Desktop\chromedriver_win32\chromedriver.exe")

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
url="https://www.amazon.in/"
driver.get(url)

# %%
search_product=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input" )
search_product
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="288d224a8a9e4bfb44588bd8c1c0821a", element="fadfcaa1-05c7-474e-a71b-a32ca1107ea8")>

# %%
asker = input("what do you want to search?")
print (asker)
# Out:
# what do you want to search?Guitar
# Guitar

# %%
search_product.send_keys(asker)

# %%
search_btn=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input" )
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="288d224a8a9e4bfb44588bd8c1c0821a", element="68f1e94a-3497-4474-be66-4929714b2e58")>

# %%
search_btn.click()

# %%
# Q1 Part B

# %%
brand_tags=driver.find_elements_by_xpath('//span [@class="a-size-base-plus a-color-base a-text-normal"]')
len(brand_tags)
# Out:
# 64

# %%
brand_titles=[]
for i in brand_tags:
    brand_titles.append(i.text)
brand_titles[1:60]
# Out:
# ['Vault EA40 41 inch Premium Spruce-Top Cutaway Acoustic Guitar',
#  'Kadence Guitar Acoustica Series, 41” Jumbo Size 6-strings Acoustic Guitar, Spruce body with Pick Guard A311 with bag',
#  'Blueberry 38C, 38" Acoustic Guitar Kit with Bag, Strap, One Pack Strings And Picks (Black)',
#  'Juarez Acoustic Guitar, 38 Inch Curved Body Cutaway, 38CUR with Bag, Strings, Pick and Strap, Black',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Blue',
#  'Intern 38C Cutaway Design Black Acoustic Guitar with Picks & Carry Bag',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Black',
#  'Kadence Frontier guitar with Online Guitar learning course, Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)',
#  '',
#  '',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black',
# ...

# %%
price_tags=driver.find_elements_by_xpath('//span[@ class="a-price a-text-price"]')
len(price_tags)
# Out:
# 63

# %%
price_titles=[]
for i in price_tags:
    price_titles.append(i.text)
price_titles[1:60]
# Out:
# ['₹17,800',
#  '₹8,999',
#  '₹6,995',
#  '₹6,990',
#  '₹6,495',
#  '₹4,995',
#  '₹9,900',
#  '₹6,495',
#  '₹6,050',
#  '',
#  '',
#  '₹6,990',
#  '₹4,999',
#  '₹6,990',
#  '₹8,289',
#  '₹7,200',
#  '₹6,990',
#  '₹6,495',
#  '₹6,500',
#  '₹14,990',
#  '₹9,499',
#  '₹5,500',
#  '₹4,999',
#  '₹7,490',
#  '₹9,999',
#  '₹1,899',
#  '₹9,500',
#  '₹6,990',
#  '₹4,999',
#  '₹4,999',
#  '₹6,990',
#  '₹6,990',
#  '₹4,999',
#  '₹7,506',
#  '₹6,990',
#  '₹4,950',
#  '₹390',
#  '₹6,990',
#  '₹8,000',
#  '₹7,500',
#  '₹18,735',
#  '₹999',
#  '₹499',
#  '₹1,999',
#  '₹6,995',
#  '₹16,999',
#  '₹9,990',
#  '₹7,200',
#  '₹8,000',
#  '₹9,499',
#  '₹10,000',
#  '₹7,100',
#  '₹9,000',
#  '₹7,999',
#  '₹6,999',
#  '₹6,995',
#  '₹6,500',
#  '₹6,999',
#  '₹7,990']

# %%
re_ex_tags=driver.find_elements_by_xpath('//span[@ class="a-color-base a-text-bold"]')
len(re_ex_tags)
# Out:
# 64

# %%
re_ex_titles=[]
for i in re_ex_tags:
    re_ex_titles.append(i.text)
re_ex_titles[1:60]
# Out:
# ['Wednesday, March 2',
#  'Tomorrow, February 28',
#  'Thursday, March 3',
#  'Tuesday, March 1',
#  'Tuesday, March 1',
#  'Today, February 27',
#  'Tuesday, March 1',
#  'Tuesday, March 1',
#  'Tomorrow, February 28',
#  'Tuesday, March 1',
#  'Wednesday, March 2',
#  'Tomorrow, February 28',
#  'Wednesday, March 2',
#  'Tuesday, March 1',
#  'Thursday, March 3',
#  'Tomorrow, February 28',
#  'Tuesday, March 1',
#  'Wednesday, March 2',
#  'Tuesday, March 1',
#  'Wednesday, March 2',
#  'Wednesday, March 2',
#  'Thursday, March 3',
#  'Wednesday, March 9',
#  'Thursday, March 3',
#  'Monday, March 7',
#  'Thursday, March 3',
#  'Tomorrow, February 28',
#  'Tomorrow, February 28',
#  'Tuesday, March 1',
#  'Wednesday, March 2',
#  'Tomorrow, February 28',
#  'Wednesday, March 2',
#  'Tuesday, March 1',
#  'Wednesday, March 2',
#  'Wednesday, March 2',
#  'Thursday, March 3',
#  'Thursday, March 3',
#  'Thursday, March 3',
#  'Thursday, March 3',
#  'Saturday, March 5',
# ...

# %%
Guitar1=pd.DataFrame()
Guitar1['brand_titles']=brand_titles[1:60]
Guitar1['price_titles']=price_titles[1:60]
Guitar1['re_ex_titles']=re_ex_titles[1:60]
Guitar1
# Out:
#                                          brand_titles price_titles  \
# 0   Vault EA40 41 inch Premium Spruce-Top Cutaway ...      ₹17,800
# 1   Kadence Guitar Acoustica Series, 41” Jumbo Siz...       ₹8,999
# 2   Blueberry 38C, 38" Acoustic Guitar Kit with Ba...       ₹6,995
# 3   Juarez Acoustic Guitar, 38 Inch Curved Body Cu...       ₹6,990
# 4   Intern INT-38C Acoustic Guitar Kit, With Bag, ...       ₹6,495
# 5   Intern 38C Cutaway Design Black Acoustic Guita...       ₹4,995
# 6   Intern INT-38C Acoustic Guitar Kit, With Bag, ...       ₹9,900
# 7   Kadence Frontier guitar with Online Guitar lea...       ₹6,495
# 8                                                           ₹6,050
# 9
# 10  Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...
# 11  Medellin 38" Acoustic Guitar Blue Burst Carbon...       ₹6,990
# 12  JUAREZ JRZ38C Right Handed Acoustic Guitar wit...       ₹4,999
# 13  Yamaha F280 Acoustic Guitar, Natural With Baja...       ₹6,990
# ...

# %%
next_btn=driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[65]/div/div/span/a[3]")
next_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="288d224a8a9e4bfb44588bd8c1c0821a", element="b3df8391-223b-43e7-97aa-dea597293153")>

# %%
next_btn.click()

# %%
brand_tags=driver.find_elements_by_xpath('//span [@class="a-size-base-plus a-color-base a-text-normal"]')
len(brand_tags)
# Out:
# 60

# %%
brand_titles=[]
for i in brand_tags:
    brand_titles.append(i.text)
brand_titles
# Out:
# ['Vault ST1 Premium Electric Guitar - Metallic Blue',
#  'Blueberry 38 Inch Acoustic Guitar Kit Inbuilt Truss Rod, with Bag, Belt, One Pack Strings And Picks (Brown)',
#  'Jyotaksh Store Givson Venus Special Guitar Combo Acoustic Guitar With Cover/Bag, String Set, Strap and 5 Plectrums (Red, Venus Special)',
#  'Clip Tuner for Guitar Bass Violin Ukulele Include Guitar Capo and Picks and Holder, winder cutter, Tuner',
#  'Henrix PRO 38 Inch 6 String Cutaway Acoustic Guitar With Die Cast Tuners, Gigbag, Picks, String Set, Strap & Cloth - Black',
#  'Musical String New Acoustic Guitar 6 string, 21 freet, 41 inches Black Mat Finished with Black Cover Bag, Picks and One Extra String Set',
#  'Kadence Frontier Series,Black Acoustic Guitar With Die Cast Keys Super Combo (Tuner, Capo, Bag, strap, strings and 3 picks)',
#  'TECHBLAZE Acoustic Guitar Tuning Peg Keys 3R+3L Guitar Machine Heads Knobs with Strap Button Locks Semi-Closed Locks Keys with Gears Screw Set (Silver 6 Pcs)',
# ...

# %%
price_tags=driver.find_elements_by_xpath('//span[@ class="a-price a-text-price"]')
len(price_tags)
# Out:
# 60

# %%
price_titles=[]
for i in price_tags:
    price_titles.append(i.text)
price_titles
# Out:
# ['₹4,995.00',
#  '₹6,495.00',
#  '₹9,999',
#  '₹7,990',
#  '₹12,999',
#  '₹1,299',
#  '₹6,000',
#  '₹6,999',
#  '₹8,800',
#  '₹749',
#  '₹6,990',
#  '₹6,995',
#  '₹15,990',
#  '₹12,999',
#  '₹2,599',
#  '₹9,999',
#  '₹6,495',
#  '₹16,999',
#  '₹9,999',
#  '₹9,999',
#  '₹6,995',
#  '₹6,995',
#  '₹10,990',
#  '₹9,999',
#  '₹9,999',
#  '₹8,995',
#  '₹8,990',
#  '₹7,100',
#  '₹1,599',
#  '₹6,990',
#  '₹1,199',
#  '₹9,999',
#  '₹10,210',
#  '₹8,999',
#  '₹599',
#  '₹8,070',
#  '₹5,500',
#  '₹6,990',
#  '₹14,280',
#  '₹4,999',
#  '₹599',
#  '₹1,499',
#  '₹7,500',
#  '₹1,999',
#  '₹16,350',
#  '₹9,999',
#  '₹7,990',
#  '₹7,999',
#  '₹9,999',
#  '₹5,999',
#  '₹23,999',
#  '₹9,999',
#  '₹11,990',
#  '₹9,999',
#  '₹9,900',
#  '₹10,990',
#  '₹6,995',
#  '₹9,999',
#  '₹9,495',
#  '₹9,900']

# %%
re_ex_tags=driver.find_elements_by_xpath('//span[@ class="a-color-base a-text-bold"]')
len(re_ex_tags)
# Out:
# 62

# %%
re_ex_titles=[]
for i in re_ex_tags:
    re_ex_titles.append(i.text)
re_ex_titles
# Out:
# ['Wednesday, March 2',
#  'Thursday, March 3',
#  'Tuesday, March 1',
#  'Friday, March 4',
#  'Friday, March 4',
#  'Wednesday, March 2',
#  'Thursday, March 3',
#  'Tuesday, March 1',
#  'Saturday, March 5',
#  'Tuesday, March 1',
#  'Tuesday, March 1',
#  'Friday, March 4',
#  'Thursday, March 3',
#  'Tuesday, March 1',
#  'Wednesday, March 2',
#  'Thursday, March 3',
#  'Tomorrow, February 28',
#  'Friday, March 4',
#  'Saturday, March 5',
#  'Saturday, March 5',
#  'Tuesday, March 1',
#  'Thursday, March 3',
#  'Thursday, March 3',
#  'Saturday, March 5',
#  'Tuesday, March 1',
#  'Tuesday, March 1',
#  'Wednesday, March 2',
#  'Tuesday, March 1',
#  'Friday, March 4',
#  'Tuesday, March 1',
#  'Friday, March 4',
#  'Saturday, March 5',
#  'Wednesday, March 2',
#  'Thursday, March 3',
#  'Friday, March 4',
#  'Tuesday, March 1',
#  'Friday, March 4',
#  'Monday, March 7',
#  'Thursday, March 3',
#  'Saturday, March 5',
#  'Tuesday, March 1',
#  'Tomorrow, February 28',
# ...

# %%
Guitar2=pd.DataFrame()
Guitar2['brand_titles']=brand_titles[1:59]
Guitar2['price_titles']=price_titles[1:59]
Guitar2['re_ex_titles']=re_ex_titles[1:59]
Guitar2
# Out:
#                                          brand_titles price_titles  \
# 0   Blueberry 38 Inch Acoustic Guitar Kit Inbuilt ...    ₹6,495.00
# 1   Jyotaksh Store Givson Venus Special Guitar Com...       ₹9,999
# 2   Clip Tuner for Guitar Bass Violin Ukulele Incl...       ₹7,990
# 3   Henrix PRO 38 Inch 6 String Cutaway Acoustic G...      ₹12,999
# 4   Musical String New Acoustic Guitar 6 string, 2...       ₹1,299
# 5   Kadence Frontier Series,Black Acoustic Guitar ...       ₹6,000
# 6   TECHBLAZE Acoustic Guitar Tuning Peg Keys 3R+3...       ₹6,999
# 7   Juârez Acoustic Guitar, 38 Inch Cutaway, JRZ38...       ₹8,800
# 8   INTERN Cutaway Design Acoustic Guitar Pack -Hu...         ₹749
# 9   Yamaha FSX80C Semi Acoustic Cutaway Guitar wit...       ₹6,990
# 10  Jyotaksh Store Givson Venus Special Guitar Com...       ₹6,995
# 11  Medellin 38" Carbon Fiber Acoustic Guitar with...      ₹15,990
# 12       Vault ST1 Premium Electric Guitar - Sunburst      ₹12,999
# ...

# %%
next_btn=driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[56]/div/div/span/a[3]" )
next_btn
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-82-d93ccaaaef7e> in <module>
# ----> 1 next_btn=driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[56]/div/div/span/a[3]" )
#       2 next_btn
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     518             stacklevel=2,
#     519         )
# --> 520         return self.find_element(by=By.XPATH, value=xpath)
#     521
#     522     def find_elements_by_xpath(self, xpath) -> WebElement:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1242             value = '[name="%s"]' % value
#    1243
# -> 1244         return self.execute(Command.FIND_ELEMENT, {
#    1245             'using': by,
#    1246             'value': value})['value']
#
# ...

# %%
next_btn.click()
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-83-77dc717d8df1> in <module>
# ----> 1 next_btn.click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      79     def click(self) -> None:
#      80         """Clicks the element."""
# ---> 81         self._execute(Command.CLICK_ELEMENT)
#      82
#      83     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     708             params = {}
#     709         params['id'] = self._id
# --> 710         return self._parent.execute(command, params)
#     711
#     712     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
# ...

# %%
brand_tags=driver.find_elements_by_xpath('//span [@class="a-size-base-plus a-color-base a-text-normal"]')
len(brand_tags)
# Out:
# 60

# %%
brand_titles=[]
for i in brand_tags:
    brand_titles.append(i.text)
brand_titles
# Out:
# ['Vault ST1 Premium Electric Guitar - Metallic Blue',
#  'Blueberry 38 Inch Acoustic Guitar Kit Inbuilt Truss Rod, with Bag, Belt, One Pack Strings And Picks (Brown)',
#  'Jyotaksh Store Givson Venus Special Guitar Combo Acoustic Guitar With Cover/Bag, String Set, Strap and 5 Plectrums (Red, Venus Special)',
#  'Clip Tuner for Guitar Bass Violin Ukulele Include Guitar Capo and Picks and Holder, winder cutter, Tuner',
#  'Henrix PRO 38 Inch 6 String Cutaway Acoustic Guitar With Die Cast Tuners, Gigbag, Picks, String Set, Strap & Cloth - Black',
#  'Musical String New Acoustic Guitar 6 string, 21 freet, 41 inches Black Mat Finished with Black Cover Bag, Picks and One Extra String Set',
#  'Kadence Frontier Series,Black Acoustic Guitar With Die Cast Keys Super Combo (Tuner, Capo, Bag, strap, strings and 3 picks)',
#  'TECHBLAZE Acoustic Guitar Tuning Peg Keys 3R+3L Guitar Machine Heads Knobs with Strap Button Locks Semi-Closed Locks Keys with Gears Screw Set (Silver 6 Pcs)',
# ...

# %%
price_tags=driver.find_elements_by_xpath('//span[@ class="a-price a-text-price"]')
len(price_tags)
# Out:
# 60

# %%
price_titles=[]
for i in price_tags:
    price_titles.append(i.text)
price_titles
# Out:
# ['₹4,995.00',
#  '₹6,495.00',
#  '₹9,999',
#  '₹7,990',
#  '₹12,999',
#  '₹1,299',
#  '₹6,000',
#  '₹6,999',
#  '₹8,800',
#  '₹749',
#  '₹6,990',
#  '₹6,995',
#  '₹15,990',
#  '₹12,999',
#  '₹2,599',
#  '₹9,999',
#  '₹6,495',
#  '₹16,999',
#  '₹9,999',
#  '₹9,999',
#  '₹6,995',
#  '₹6,995',
#  '₹10,990',
#  '₹9,999',
#  '₹9,999',
#  '₹8,995',
#  '₹8,990',
#  '₹7,100',
#  '₹1,599',
#  '₹6,990',
#  '₹1,199',
#  '₹9,999',
#  '₹10,210',
#  '₹8,999',
#  '₹599',
#  '₹8,070',
#  '₹5,500',
#  '₹6,990',
#  '₹14,280',
#  '₹4,999',
#  '₹599',
#  '₹1,499',
#  '₹7,500',
#  '₹1,999',
#  '₹16,350',
#  '₹9,999',
#  '₹7,990',
#  '₹7,999',
#  '₹9,999',
#  '₹5,999',
#  '₹23,999',
#  '₹9,999',
#  '₹11,990',
#  '₹9,999',
#  '₹9,900',
#  '₹10,990',
#  '₹6,995',
#  '₹9,999',
#  '₹9,495',
#  '₹9,900']

# %%
re_ex_tags=driver.find_elements_by_xpath('//span[@ class="a-color-base a-text-bold"]')
len(re_ex_tags)
# Out:
# 62

# %%
re_ex_titles=[]
for i in re_ex_tags:
    re_ex_titles.append(i.text)
re_ex_titles
# Out:
# ['Wednesday, March 2',
#  'Thursday, March 3',
#  'Tuesday, March 1',
#  'Friday, March 4',
#  'Friday, March 4',
#  'Wednesday, March 2',
#  'Thursday, March 3',
#  'Tuesday, March 1',
#  'Saturday, March 5',
#  'Tuesday, March 1',
#  'Tuesday, March 1',
#  'Friday, March 4',
#  'Thursday, March 3',
#  'Tuesday, March 1',
#  'Wednesday, March 2',
#  'Thursday, March 3',
#  'Tomorrow, February 28',
#  'Friday, March 4',
#  'Saturday, March 5',
#  'Saturday, March 5',
#  'Tuesday, March 1',
#  'Thursday, March 3',
#  'Thursday, March 3',
#  'Saturday, March 5',
#  'Tuesday, March 1',
#  'Tuesday, March 1',
#  'Wednesday, March 2',
#  'Tuesday, March 1',
#  'Friday, March 4',
#  'Tuesday, March 1',
#  'Friday, March 4',
#  'Saturday, March 5',
#  'Wednesday, March 2',
#  'Thursday, March 3',
#  'Friday, March 4',
#  'Tuesday, March 1',
#  'Friday, March 4',
#  'Monday, March 7',
#  'Thursday, March 3',
#  'Saturday, March 5',
#  'Tuesday, March 1',
#  'Tomorrow, February 28',
# ...

# %%
Guitar3=pd.DataFrame()
Guitar3['brand_titles']=brand_titles[0:60]
Guitar3['price_titles']=price_titles[0:60]
Guitar3['re_ex_titles']=re_ex_titles[0:60]
Guitar3
# Out:
#                                          brand_titles price_titles  \
# 0   Vault ST1 Premium Electric Guitar - Metallic Blue    ₹4,995.00
# 1   Blueberry 38 Inch Acoustic Guitar Kit Inbuilt ...    ₹6,495.00
# 2   Jyotaksh Store Givson Venus Special Guitar Com...       ₹9,999
# 3   Clip Tuner for Guitar Bass Violin Ukulele Incl...       ₹7,990
# 4   Henrix PRO 38 Inch 6 String Cutaway Acoustic G...      ₹12,999
# 5   Musical String New Acoustic Guitar 6 string, 2...       ₹1,299
# 6   Kadence Frontier Series,Black Acoustic Guitar ...       ₹6,000
# 7   TECHBLAZE Acoustic Guitar Tuning Peg Keys 3R+3...       ₹6,999
# 8   Juârez Acoustic Guitar, 38 Inch Cutaway, JRZ38...       ₹8,800
# 9   INTERN Cutaway Design Acoustic Guitar Pack -Hu...         ₹749
# 10  Yamaha FSX80C Semi Acoustic Cutaway Guitar wit...       ₹6,990
# 11  Jyotaksh Store Givson Venus Special Guitar Com...       ₹6,995
# 12  Medellin 38" Carbon Fiber Acoustic Guitar with...      ₹15,990
# ...

# %%
Final=[Guitar1,Guitar2,Guitar3]
result=pd.concat(Final)
Final
# Out:
# [                                         brand_titles price_titles  \
#  0   Vault EA40 41 inch Premium Spruce-Top Cutaway ...      ₹17,800
#  1   Kadence Guitar Acoustica Series, 41” Jumbo Siz...       ₹8,999
#  2   Blueberry 38C, 38" Acoustic Guitar Kit with Ba...       ₹6,995
#  3   Juarez Acoustic Guitar, 38 Inch Curved Body Cu...       ₹6,990
#  4   Intern INT-38C Acoustic Guitar Kit, With Bag, ...       ₹6,495
#  5   Intern 38C Cutaway Design Black Acoustic Guita...       ₹4,995
#  6   Intern INT-38C Acoustic Guitar Kit, With Bag, ...       ₹9,900
#  7   Kadence Frontier guitar with Online Guitar lea...       ₹6,495
#  8                                                           ₹6,050
#  9
#  10  Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...
#  11  Medellin 38" Acoustic Guitar Blue Burst Carbon...       ₹6,990
#  12  JUAREZ JRZ38C Right Handed Acoustic Guitar wit...       ₹4,999
#  13  Yamaha F280 Acoustic Guitar, Natural With Baja...       ₹6,990
# ...

# %%
import pandas as pd
df=pd.DataFrame(Final)
df.to_csv('file1.csv',index=False)

# %%
driver.close()

# %%
# Question 3

# %%
driver=webdriver.Chrome(r"C:\Users\cjash\Desktop\chromedriver_win32\chromedriver.exe")

# %%
url="http://images.google.com/"
driver.get(url)

# %%
search_job=driver.find_element_by_xpath("/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div[1]/div/div[2]/input" )
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4f486bc744e59c06d6ff12321ed35805", element="602f522a-71f7-4c48-99d8-434568d5ebd2")>

# %%
search_job.send_keys("Fruits")

# %%
search_btn=driver.find_element_by_class_name("zgAlFc" )
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4f486bc744e59c06d6ff12321ed35805", element="16947cbc-e50d-4b92-a9cc-419fcb6c9058")>

# %%
search_btn.click()

# %%
image_tags=driver.find_elements_by_xpath('//div[@ class="isv-r PNCib MSM1fd BUooTd"]')
len(image_tags)
# Out:
# 48

# %%
image_titles=[]
for i in image_tags:
    image_titles.append(i.text)
image_titles[1:10]
# Out:
# ['Buy Jumbo All in One Fruits Chart for Kids | My First Early Learning Educational Chart for Homeschooling, Kindergarten and Nursery Children | 39.25 x 27.25 in Book Online at Low Prices\nOne Fruits Chart for Kids ...\namazon.in',
#  'Fruits\nFruits\nhealthyeating.org',
#  'Buy Fruits Chart (50 x 70 cm) Book Online at Low Prices in India | Fruits Chart (50 x 70 cm) Reviews & Ratings - Amazon.in\nBuy Fruits Chart (50 x 70 cm) Book ...\namazon.in',
#  'Most Popular Fruits In The World - WorldAtlas\nMost Popular Fruits In The World ...\nworldatlas.com',
#  'Fruit - Wikipedia\nFruit - Wikipedia\nen.wikipedia.org',
#  'Pin on English\nPin on English\npinterest.com',
#  'Winter Fruits: List of 15+ Types of Fruits You Can Find in the Winter - ESL Forums | Winter fruit, Fruit names, Fruit list\nWinter Fruits: List of 15+ Types of ...\npinterest.com',
#  'How to Store Fruit to Keep them Fresh - Unlock Food\nHow to Store Fruit to Keep them Fresh ...\nunlockfood.ca',
# ...

# %%
driver.close()

# %%
driver=webdriver.Chrome(r"C:\Users\cjash\Desktop\chromedriver_win32\chromedriver.exe")

# %%
url="http://images.google.com/"
driver.get(url)

# %%
search_job=driver.find_element_by_xpath("/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div[1]/div/div[2]/input" )
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="629ad39015a007a647e8505f9058f0b2", element="ff033ae6-cff4-4b8e-b6aa-ee1214263b70")>

# %%
search_job.send_keys("Cars")

# %%
search_btn=driver.find_element_by_class_name("zgAlFc" )
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="629ad39015a007a647e8505f9058f0b2", element="6f2fb01f-a493-4a55-849c-886d5f51ec42")>

# %%
search_btn.click()

# %%
image_tags=driver.find_elements_by_xpath('//div[@ class="isv-r PNCib MSM1fd BUooTd"]')
len(image_tags)
# Out:
# 48

# %%
image_titles=[]
for i in image_tags:
    image_titles.append(i.text)
image_titles[1:10]
# Out:
# ['Most Expensive Cars In The World (2021 Update) | Motor1.com\nMost Expensive Cars In The World (2021 ...\nmotor1.com',
#  'Cool Cars - Coolest Cars, SUVs and Trucks of 2020-2021 | Motor1.com\nCool Cars - Coolest Cars, SUVs and ...\nmotor1.com',
#  'The Top 14 Luxury Cars of 2019 - Elite Traveler\nThe Top 14 Luxury Cars of 2019 - Elite ...\nelitetraveler.com',
#  'Mercedes-Benz Concept Cars.\nMercedes-Benz Concept Cars.\nmercedes-benz.com',
#  'Cars (film) - Wikipedia\nCars (film) - Wikipedia\nen.wikipedia.org',
#  'Best New Cars Coming Out in 2021 | New Car Reviews\nBest New Cars Coming Out in 2021 | New ...\npopularmechanics.com',
#  'The 12 Most Expensive Cars on the Market | U.S. News\nThe 12 Most Expensive Cars on the ...\ncars.usnews.com',
#  'TOP 10 CRAZIEST CONCEPT CARS 2020 - YouTube\nTOP 10 CRAZIEST CONCEPT CARS 2020 - YouTube\nyoutube.com',
#  'TOP 10 Craziest Concept Cars 2021 - YouTube\nTOP 10 Craziest Concept Cars 2021 - YouTube\nyoutube.com']

# %%
driver.close()

# %%
driver=webdriver.Chrome(r"C:\Users\cjash\Desktop\chromedriver_win32\chromedriver.exe")

# %%
url="http://images.google.com/"
driver.get(url)

# %%
search_job=driver.find_element_by_xpath("/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div[1]/div/div[2]/input" )
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="21bd2625023288678a4a73bcf704a13d", element="8ecf3d2b-596d-46c7-91a0-3500f1de8e91")>

# %%
search_job.send_keys("Cake")

# %%
search_btn=driver.find_element_by_class_name("zgAlFc" )
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="21bd2625023288678a4a73bcf704a13d", element="2947a7ef-9b54-438a-8dea-542f56cbf7dc")>

# %%
search_btn.click()

# %%
image_tags=driver.find_elements_by_xpath('//h3[@class="bytUYc"]')
len(image_tags)
# Out:
# 48

# %%
image_titles=[]
for i in image_tags:
    image_titles.append(i.text)
image_titles[0:10]
# Out:
# ['Cake - Wikipedia',
#  "Birthday Cake Recipe | Land O'Lakes",
#  "Triple Chocolate Cake Recipe - Sally's Baking Addiction",
#  'The Ultimate Decadent Chocolate-and-Cream Layer Cake Recipe | Cooking Light',
#  'Best Birthday Cake - Handle the Heat',
#  'Birthday Cakes Pictures | Download Free Images on Unsplash',
#  'Black Forest Cake - Liv for Cake',
#  'The Birthday Cake! - Sprinkle Bakes | Recipe | Sprinkles birthday cake, Birthday cake flavors, Image birthday cake',
#  'Chocolate Cake - Preppy Kitchen',
#  'Rainbow Unicorn Cake » Hummingbird High']

# %%
driver.close()

# %%
driver=webdriver.Chrome(r"C:\Users\cjash\Desktop\chromedriver_win32\chromedriver.exe")

# %%
url="http://images.google.com/"
driver.get(url)

# %%
search_job=driver.find_element_by_xpath("/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div[1]/div/div[2]/input" )
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="aa85f1332006ea4c859eeb2473a6069b", element="08c7fb1d-7300-4756-a9ce-ddb579413002")>

# %%
search_job.send_keys("Machine Learning")

# %%
search_btn=driver.find_element_by_class_name("zgAlFc" )
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="aa85f1332006ea4c859eeb2473a6069b", element="a609ee1f-a321-4975-a4da-45ec8a7742a9")>

# %%
search_btn.click()

# %%
image_tags=driver.find_elements_by_xpath('//div[@class="isv-r PNCib MSM1fd BUooTd"]')
len(image_tags)
# Out:
# 48

# %%
image_titles=[]
for i in image_tags:
    image_titles.append(i.text)
image_titles[0:10]
# Out:
# ['What You Need To Know About Machine Learning\nMachine Learning\nforbes.com',
#  'Machine Learning Tutorial - All the Essential Concepts in Single Tutorial - DataFlair\nMachine Learning Tutorial - All the ...\ndata-flair.training',
#  'Why Machine Learning Needs Semantics Not Just Statistics\nWhy Machine Learning Needs Semantics ...\nforbes.com',
#  "Machine Learning Algorithms In Layman's Terms, Part 1 | by Audrey Lorberfeld | Towards Data Science\nMachine Learning Algorithms In Layman's ...\ntowardsdatascience.com",
#  'Machine learning in industry | ATRIA Innovation\nMachine learning in industry | ATRIA ...\natriainnovation.com',
#  'Artificial Intelligence vs. Machine Learning vs. Deep Learning | Towards Data Science\nMachine Learning vs. Deep Learning ...\ntowardsdatascience.com',
#  'Machine Learning - GeeksforGeeks\nMachine Learning - GeeksforGeeks\ngeeksforgeeks.org',
# ...

# %%
driver.close()

# %%
driver=webdriver.Chrome(r"C:\Users\cjash\Desktop\chromedriver_win32\chromedriver.exe")

# %%
url="http://images.google.com/"
driver.get(url)

# %%
search_job=driver.find_element_by_xpath("/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div[1]/div/div[2]/input" )
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5e740046a732e50d68636027bcb3b359", element="3c49d891-62d8-43bd-82ad-f18a21ca94b4")>

# %%
search_job.send_keys("Guitar")

# %%
search_btn=driver.find_element_by_class_name("zgAlFc" )
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5e740046a732e50d68636027bcb3b359", element="0da9e9c8-3e6f-4fb9-9aed-d97f56594420")>

# %%
search_btn.click()

# %%
image_tags=driver.find_elements_by_xpath('//div[@class="isv-r PNCib MSM1fd BUooTd"]')
len(image_tags)
# Out:
# 48

# %%
image_titles=[]
for i in image_tags:
    image_titles.append(i.text)
image_titles[0:10]
# Out:
# ['Guitar - Wikipedia\nGuitar - Wikipedia\nen.wikipedia.org',
#  'Yamaha F280 Natural Acoustic Guitar Made in Guitar Online Store In India\nYamaha F280 Natural Acoustic Guitar ...\nyamahamusicstore.in · In stock',
#  'Jasmine S35 Acoustic Guitar Natural | Solid Citka Spruce : Amazon.in: Musical Instruments\nJasmine S35 Acoustic Guitar Natural ...\namazon.in',
#  'Yamaha PACIFICA012 Electric Guitar, Red Metallic : Amazon.in: Musical Instruments\nYamaha PACIFICA012 Electric Guitar, Red ...\namazon.in',
#  'Acoustic Guitar Techniques to Move Past Beginner Level – Berklee Online Take Note\nAcoustic Guitar Techniques to Move Past ...\nonline.berklee.edu',
#  'Richtone Acoustic Gutiar - 39 inch | Buy Beginner Guitars online in India | JohnsMusic.in\nRichtone Acoustic Gutiar - 39 inch ...\njohnsmusic.in · In stock',
#  'guitar summary | Britannica\nguitar summary | Britannica\nbritannica.com',
# ...

# %%
driver.close()

# %%
# Questiuon 4

# %%
driver=webdriver.Chrome(r"C:\Users\cjash\Desktop\chromedriver_win32\chromedriver.exe")

# %%
url="https://www.flipkart.com/"
driver.get(url)

# %%
search_job=driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input" )
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4468d522766ae16b08a77b4f2d41735d", element="d346a1ce-7585-46e8-a22d-1c30557cdc46")>

# %%
search_job.send_keys("Samsung phones")

# %%
search_btn=driver.find_element_by_class_name("L0Z3Pu" )
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4468d522766ae16b08a77b4f2d41735d", element="5fe7bc64-4615-4b33-8a83-2628f3c95d69")>

# %%
search_btn.click()

# %%
brand_tags=driver.find_elements_by_xpath('//div [@class="_4rR01T"]')
len(brand_tags)
# Out:
# 24

# %%
brand_titles=[]
for i in brand_tags:
    brand_titles.append(i.text)
brand_titles
# Out:
# ['SAMSUNG Galaxy F12 (Sky Blue, 128 GB)',
#  'SAMSUNG Galaxy F22 (Denim Blue, 128 GB)',
#  'SAMSUNG Galaxy F22 (Denim Black, 128 GB)',
#  'SAMSUNG Galaxy F22 (Denim Black, 64 GB)',
#  'SAMSUNG Galaxy M12 (Blue, 128 GB)',
#  'SAMSUNG Galaxy F42 5G (Matte Black, 128 GB)',
#  'SAMSUNG Galaxy M12 (Black, 128 GB)',
#  'SAMSUNG Galaxy M32 (Light Blue, 128 GB)',
#  'SAMSUNG Galaxy M12 (Blue, 64 GB)',
#  'SAMSUNG Galaxy F42 5G (Matte Aqua, 128 GB)',
#  'SAMSUNG Galaxy F22 (Denim Blue, 64 GB)',
#  'SAMSUNG Galaxy M12 (Black, 64 GB)',
#  'SAMSUNG Galaxy M12 (White, 64 GB)',
#  'SAMSUNG M21 2021 Edition (Charcoal Black, 64 GB)',
#  'SAMSUNG Galaxy M32 (Black, 64 GB)',
#  'SAMSUNG Galaxy M12 (White, 128 GB)',
#  'SAMSUNG Guru GT',
#  'SAMSUNG Galaxy A22 5G (Violet, 128 GB)',
#  'SAMSUNG GURU 1200',
#  'SAMSUNG GURU GT',
#  'SAMSUNG Metro 313 Dual Sim',
#  'SAMSUNG Galaxy A20s (Green, 32 GB)',
#  'SAMSUNG M32 5G (Sky blue, 128 GB)',
#  'SAMSUNG GURU MUSIC 2']

# %%
memory_tags=driver.find_elements_by_xpath('//div[@class="fMghEO"]')
len(memory_tags)
# Out:
# 24

# %%
memory_titles=[]
for i in memory_tags:
    memory_titles.append(i.text)
memory_titles
# Out:
# ['4 GB RAM | 128 GB ROM | Expandable Upto 512 GB\n16.55 cm (6.515 inch) HD+ Display\n48MP + 5MP + 2MP + 2MP | 8MP Front Camera\n6000 mAh Lithium-ion Battery\nExynos 850 Processor\n1 Year Warranty Provided by the Manufacturer from Date of Purchase',
#  '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB\n16.26 cm (6.4 inch) HD+ Display\n48MP + 8MP + 2MP + 2MP | 13MP Front Camera\n6000 mAh Lithium-ion Battery\nMediaTek Helio G80 Processor\n1 Year Warranty Provided by the Manufacturer from Date of Purchase',
#  '6 GB RAM | 128 GB ROM | Expandable Upto 1 TB\n16.26 cm (6.4 inch) HD+ Display\n48MP + 8MP + 2MP + 2MP | 13MP Front Camera\n6000 mAh Lithium-ion Battery\nMediaTek Helio G80 Processor\n1 Year Warranty Provided by the Manufacturer from Date of Purchase',
# ...

# %%
price_tags=driver.find_elements_by_xpath('//div[@class="_30jeq3 _1_WHN1"]')
len(price_tags)
# Out:
# 24

# %%
price_titles=[]
for i in price_tags:
    price_titles.append(i.text)
price_titles
# Out:
# ['₹10,499',
#  '₹14,999',
#  '₹14,999',
#  '₹12,999',
#  '₹13,118',
#  '₹16,999',
#  '₹13,178',
#  '₹16,890',
#  '₹10,949',
#  '₹16,999',
#  '₹12,999',
#  '₹10,989',
#  '₹10,989',
#  '₹12,974',
#  '₹14,346',
#  '₹13,159',
#  '₹1,570',
#  '₹19,999',
#  '₹1,555',
#  '₹1,565',
#  '₹2,589',
#  '₹10,629',
#  '₹18,628',
#  '₹2,010']

# %%
df=pd.DataFrame()
df['brand_titles']=brand_titles[0:24]
df['memory_titles']=memory_titles[0:24]
df['price_titles']=price_titles[0:24]
df
# Out:
#                                         brand_titles  \
# 0              SAMSUNG Galaxy F12 (Sky Blue, 128 GB)
# 1            SAMSUNG Galaxy F22 (Denim Blue, 128 GB)
# 2           SAMSUNG Galaxy F22 (Denim Black, 128 GB)
# 3            SAMSUNG Galaxy F22 (Denim Black, 64 GB)
# 4                  SAMSUNG Galaxy M12 (Blue, 128 GB)
# 5        SAMSUNG Galaxy F42 5G (Matte Black, 128 GB)
# 6                 SAMSUNG Galaxy M12 (Black, 128 GB)
# 7            SAMSUNG Galaxy M32 (Light Blue, 128 GB)
# 8                   SAMSUNG Galaxy M12 (Blue, 64 GB)
# 9         SAMSUNG Galaxy F42 5G (Matte Aqua, 128 GB)
# 10            SAMSUNG Galaxy F22 (Denim Blue, 64 GB)
# 11                 SAMSUNG Galaxy M12 (Black, 64 GB)
# 12                 SAMSUNG Galaxy M12 (White, 64 GB)
# 13  SAMSUNG M21 2021 Edition (Charcoal Black, 64 GB)
# 14                 SAMSUNG Galaxy M32 (Black, 64 GB)
# 15                SAMSUNG Galaxy M12 (White, 128 GB)
# 16                                   SAMSUNG Guru GT
# ...

# %%
import pandas as pd
df1=pd.DataFrame(df)
df1.to_csv('file2.csv',index=False)

# %%
driver.close()

# %%
# Question 5

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
url="https://www.google.com/maps"
driver.get(url)

# %%
search_city=driver.find_element_by_class_name("tactile-searchbox-input" )
search_city
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="be2301550223e9372c195da9366f390e", element="59d56681-58c8-4ea2-80d3-f8894bc5eb70")>

# %%
search_city.send_keys("Mumbai")

# %%
search_btn=driver.find_element_by_xpath("/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/div[1]/button")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="be2301550223e9372c195da9366f390e", element="3e371a12-bdfd-43d3-bd70-4ac39b0d944a")>

# %%
search_btn.click()

# %%
search_loc=driver.find_element_by_xpath("/html/body/div[3]/div[9]/div[1]/div[3]/canvas")
search_loc
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="be2301550223e9372c195da9366f390e", element="dc3b901b-634e-4651-8f5c-58bee7677911")>

# %%
# Question 6

# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://trak.in/india-startup-funding-investment-2015/"
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]>
# 	<html class="ie ie8" lang="en-US"> <![endif]--><!--[if IE 9]>
# 	<html class="ie ie9" lang="en-US"> <![endif]--><!--[if gt IE 9]><!--><html lang="en-US"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://trak.in/xmlrpc.php" rel="pingback"/>
# <title>Indian Startup Funding And Investment Chart [2021] – Trak.in – Indian Business of Tech, Mobile &amp; Startups</title>
# <link href="https://trak.in/india-startup-funding-investment-2015/amp/" rel="amphtml"/><meta content="AMP for WP 1.0.64.1" name="generator"/>
# <meta content="en_us" property="og:locale"/>
# <meta content="Trak.in - Indian Business of Tech, Mobile &amp; Startups" property="og:site_name"/>
# <meta content="https://trak.in/india-startup-funding-investment-2015/" property="og:url"/>
# ...

# %%
table1 = soup.find_all('div', attrs={"class":'dataTables_wrapper no-footer'})
table1headers = []
for i in soup.find_all('th'):
    title = i.text
    headers.append(title)
headers
# Out:
# ['Sr. No.',
#  'Date (dd/mm/yyyy)',
#  'Startup Name',
#  'Industry / Vertical',
#  'Sub-Vertical',
#  'City / Location',
#  "Investors' Name",
#  'Investment Type',
#  'Amount (In USD)',
#  'Sr. No.',
#  'Date (dd/mm/yyyy)',
#  'Startup Name',
#  'Industry / Vertical',
#  'Sub-Vertical',
#  'City / Location',
#  "Investors' Name",
#  'Investment Type',
#  'Amount (In USD)',
#  'Sr. No.',
#  'Date (dd/mm/yyyy)',
#  'Startup Name',
#  'Industry / Vertical',
#  'Sub-Vertical',
#  'City / Location',
#  "Investors' Name",
#  'Investment Type',
#  'Amount (In USD)',
#  'Sr. No.',
#  'Date (dd/mm/yyyy)',
#  'Startup Name',
#  'Industry / Vertical',
#  'Sub-Vertical',
#  'City / Location',
#  "Investors' Name",
#  'Investment Type',
#  'Amount (In USD)',
#  'Sr. No.',
#  'Date (dd/mm/yyyy)',
#  'Startup Name',
#  'Industry / Vertical',
#  'Sub-Vertical',
#  'City / Location',
#  "Investors' Name",
#  'Investment Type',
#  'Amount (In USD)',
#  'Sr. No.',
#  'Date (dd/mm/yyyy)',
# ...

# %%
headers = []
for i in soup.find_all('th'):
    title = i.text
    headers.append(title)
headers
# Out:
# ['Sr. No.',
#  'Date (dd/mm/yyyy)',
#  'Startup Name',
#  'Industry / Vertical',
#  'Sub-Vertical',
#  'City / Location',
#  "Investors' Name",
#  'Investment Type',
#  'Amount (In USD)',
#  'Sr. No.',
#  'Date (dd/mm/yyyy)',
#  'Startup Name',
#  'Industry / Vertical',
#  'Sub-Vertical',
#  'City / Location',
#  "Investors' Name",
#  'Investment Type',
#  'Amount (In USD)',
#  'Sr. No.',
#  'Date (dd/mm/yyyy)',
#  'Startup Name',
#  'Industry / Vertical',
#  'Sub-Vertical',
#  'City / Location',
#  "Investors' Name",
#  'Investment Type',
#  'Amount (In USD)',
#  'Sr. No.',
#  'Date (dd/mm/yyyy)',
#  'Startup Name',
#  'Industry / Vertical',
#  'Sub-Vertical',
#  'City / Location',
#  "Investors' Name",
#  'Investment Type',
#  'Amount (In USD)',
#  'Sr. No.',
#  'Date (dd/mm/yyyy)',
#  'Startup Name',
#  'Industry / Vertical',
#  'Sub-Vertical',
#  'City / Location',
#  "Investors' Name",
#  'Investment Type',
#  'Amount (In USD)',
#  'Sr. No.',
#  'Date (dd/mm/yyyy)',
# ...

# %%
mydata = pd.DataFrame(columns = headers)
mydata
# Out:
# Empty DataFrame
# ...

# %%
table1rows = []
for i in soup.find_all('tr'):
    title = i.text
    table1rows.append(title)
table1rows
# Out:
# ["\nSr. No.Date (dd/mm/yyyy)Startup NameIndustry / VerticalSub-VerticalCity / LocationInvestors' NameInvestment TypeAmount (In USD)\n",
#  '\n101/04/2021BYJU’SEdu-techOnline tutoringBengaluruInnoven CapitalSeries F460,000,000\n',
#  '\n205/04/2021MeeshoE-commerceOnline reselling platformBengaluruSoftBank Vision Fund 2Series E300,000,000\n',
#  '\n314/04/2021SwiggyOnline Food DeliveryOnline Food DeliveryBengaluruAmansa Holdings, Carmignac, Falcon Edge Capital, Goldman Sachs, Think InvestmentsSeries J343,000,000\n',
#  '\n407/04/2021GrowwFinTechInvestment platformBengaluruMC Global Edtech, B Capital, Baron, othersSeries D83,000,000\n',
#  '\n514/04/2021BeldaraE-commerceGlobal B2B marketplaceMumbaiHindustan Media VenturesVenture7,400,000\n',
#  "\nSr. No.Date (dd/mm/yyyy)Startup NameIndustry / VerticalSub-VerticalCity / LocationInvestors' NameInvestment TypeAmount (In USD)\n",
# ...

# %%
table2 = soup.find_all('div',id='tablepress-55_wrapper')
table2headers = []
for i in soup.find_all('th'):
    title = i.text
    table2headers.append(title)
table2headers
# Out:
# ['Sr. No.',
#  'Date (dd/mm/yyyy)',
#  'Startup Name',
#  'Industry / Vertical',
#  'Sub-Vertical',
#  'City / Location',
#  "Investors' Name",
#  'Investment Type',
#  'Amount (In USD)',
#  'Sr. No.',
#  'Date (dd/mm/yyyy)',
#  'Startup Name',
#  'Industry / Vertical',
#  'Sub-Vertical',
#  'City / Location',
#  "Investors' Name",
#  'Investment Type',
#  'Amount (In USD)',
#  'Sr. No.',
#  'Date (dd/mm/yyyy)',
#  'Startup Name',
#  'Industry / Vertical',
#  'Sub-Vertical',
#  'City / Location',
#  "Investors' Name",
#  'Investment Type',
#  'Amount (In USD)',
#  'Sr. No.',
#  'Date (dd/mm/yyyy)',
#  'Startup Name',
#  'Industry / Vertical',
#  'Sub-Vertical',
#  'City / Location',
#  "Investors' Name",
#  'Investment Type',
#  'Amount (In USD)',
#  'Sr. No.',
#  'Date (dd/mm/yyyy)',
#  'Startup Name',
#  'Industry / Vertical',
#  'Sub-Vertical',
#  'City / Location',
#  "Investors' Name",
#  'Investment Type',
#  'Amount (In USD)',
#  'Sr. No.',
#  'Date (dd/mm/yyyy)',
# ...

# %%
table2rows = []
for i in soup.find_all('tr'):
    title = i.text
    table2rows.append(title)
table2rows
# Out:
# ["\nSr. No.Date (dd/mm/yyyy)Startup NameIndustry / VerticalSub-VerticalCity / LocationInvestors' NameInvestment TypeAmount (In USD)\n",
#  '\n101/04/2021BYJU’SEdu-techOnline tutoringBengaluruInnoven CapitalSeries F460,000,000\n',
#  '\n205/04/2021MeeshoE-commerceOnline reselling platformBengaluruSoftBank Vision Fund 2Series E300,000,000\n',
#  '\n314/04/2021SwiggyOnline Food DeliveryOnline Food DeliveryBengaluruAmansa Holdings, Carmignac, Falcon Edge Capital, Goldman Sachs, Think InvestmentsSeries J343,000,000\n',
#  '\n407/04/2021GrowwFinTechInvestment platformBengaluruMC Global Edtech, B Capital, Baron, othersSeries D83,000,000\n',
#  '\n514/04/2021BeldaraE-commerceGlobal B2B marketplaceMumbaiHindustan Media VenturesVenture7,400,000\n',
#  "\nSr. No.Date (dd/mm/yyyy)Startup NameIndustry / VerticalSub-VerticalCity / LocationInvestors' NameInvestment TypeAmount (In USD)\n",
# ...

# %%
# Question 7

# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://www.digit.in/top-products/top-10-laptops-5.html/"
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, user-scalable=1" name="viewport"/>
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://www.digit.in/images/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="https://www.digit.in/css/top-10.css?v=423" rel="stylesheet" type="text/css"/>
# <link href="https://ajax.googleapis.com/" rel="preconnect"/>
# <link href="https://ajax.googleapis.com/" rel="dns-prefetch"/>
# <link href="https://static.digit.in/" rel="preconnect"/>
# <link href="https://static.digit.in/" rel="dns-prefetch"/>
# <link href="https://securepubads.g.doubleclick.net/" rel="preconnect"/>
# <link href="https://securepubads.g.doubleclick.net/" rel="dns-prefetch"/>
# <link href="https://connect.facebook.net/" rel="dns-prefetch"/>
# <link href="https://www.gstatic.com/" rel="dns-prefetch"/>
# <link href="https://cdnjs.cloudflare.com/" rel="preconnect"/>
# ...

# %%
table1 = soup.find('table', id='summtable')
table1
# Out:
# <table id="summtable">
# <thead>
# <tr>
# <th>Product Name</th>
# <th>Seller</th>
# <th>Price</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Apple 16-Inch MacBook Pro M1 Max</td>
# <td class="smmerchant">
# N/A
# </td>
# <td class="smprice">
# ₹ 329,900
# </td>
# </tr>
# <tr>
# <td>Dell XPS 13 (9310) - 2021</td>
# <td class="smmerchant">
# Croma
# </td>
# <td class="smprice">
# ₹ 201,990
# </td>
# </tr>
# <tr>
# <td>ASUS ROG Flow x13</td>
# <td class="smmerchant">
# Flipkart
# </td>
# <td class="smprice">
# ₹ 154,990
# </td>
# </tr>
# <tr>
# <td>Apple MacBook Air M1</td>
# <td class="smmerchant">
# Croma
# </td>
# <td class="smprice">
# ₹ 83,900
# </td>
# </tr>
# <tr>
# <td>Lenovo Yoga Slim 7i Carbon</td>
# <td class="smmerchant">
# Amazon
# </td>
# <td class="smprice">
# ₹ 106,999
# </td>
# </tr>
# <tr>
# <td>ASUS ExpertBook B9 (B9400)</td>
# <td class="smmerchant">
# Croma
# </td>
# <td class="smprice">
# ₹ 167,994
# </td>
# </tr>
# <tr>
# <td>.Acer Nitro 5</td>
# ...

# %%
headers = []
for i in table1.find_all('th'):
    title = i.text
    headers.append(title)
headers
# Out:
# ['Product Name', 'Seller', 'Price']

# %%
mydata = pd.DataFrame(columns = headers)
mydata
# Out:
# Empty DataFrame
# Columns: [Product Name, Seller, Price]
# Index: []

# %%
for j in table1.find_all('tr')[1:]:
    row_data = j.find_all('td')
    row = [i.text for i in row_data]
    length = len(mydata)
mydata.loc[length] = row
mydata
# Out:
#                                      Product Name        Seller          Price
# 0                           ASUS ROG Zephyrus G14     \nCroma\n  \n₹ 144,990\n
# 1                Apple 16-Inch MacBook Pro M1 Max       \nN/A\n  \n₹ 329,900\n
# 2                       Dell XPS 13 (9310) - 2021     \nCroma\n  \n₹ 201,990\n
# 3                               ASUS ROG Flow x13  \nFlipkart\n  \n₹ 154,990\n
# 4                            Apple MacBook Air M1     \nCroma\n   \n₹ 83,900\n
# 5                      Lenovo Yoga Slim 7i Carbon    \nAmazon\n  \n₹ 106,999\n
# 6                      ASUS ExpertBook B9 (B9400)     \nCroma\n  \n₹ 167,994\n
# 7                                   .Acer Nitro 5       \nN/A\n   \n₹ 95,990\n
# 8                            Acer Aspire 7 Gaming     \nCroma\n   \n₹ 53,490\n
# 9   MSI Pulse GL66 gaming laptop 11th Gen Core i7       \nN/A\n        \nN/A\n
# 10                          ASUS ROG Zephyrus G14     \nCroma\n  \n₹ 144,990\n
# ...

# %%
# Question 8

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
url="https://www.forbes.com/billionaires/"
driver.get(url)

# %%
name_tags=driver.find_elements_by_xpath('//div [@class="personName"]')
len(name_tags)
# Out:
# 200

# %%
name_titles=[]
for i in name_tags:
    name_titles.append(i.text)
name_titles
# Out:
# ['Zhou Wei family',
#  'Zhong Naixiong',
#  'Zhao Meiguang',
#  'Zhang Yuqiang',
#  'Daniel Yong Zhang',
#  'Yu De-Chao',
#  'Yao Hsiao Tung',
#  'Mark Haoyong Yang',
#  'Vadim Yakunin',
#  'Xu Jin',
#  'Xia Zhisheng & family',
#  'Sandy Weill',
#  'J. Wayne Weaver',
#  'Wang Wenjian',
#  'Wang Qiangxiang',
#  'Vlad Vendrow & family',
#  'Murat Vargi',
#  'Ruben Vardanyan',
#  'Surin Upatkoon',
#  'Tsai Chi-jui',
#  'Tong Judy Wenhong',
#  'Rit Thirakomen',
#  'Vlad Tenev',
#  'Manny Stul',
#  'Axel Stawski',
#  'Veronica Squinzi',
#  'Marco Squinzi',
#  'Zakhar Smushkin',
#  'Scott Smith',
#  'Shin Dong-joo',
#  'Alan Rydge',
#  'Hartley Rogers',
#  'Jorge Rodriguez Rodriguez',
#  'Anton Rabie',
#  'Maria Pinheiro',
#  'Tyler Perry',
#  'David Penaloza Alanis',
#  'George Pedersen',
#  'Vitaly Orlov',
#  'Mofatraj Munot',
#  'Michael McCain',
#  'Mao Huihua',
#  'Rafique Malik',
#  'Sergei Makhlai',
#  'Ma Hong',
#  'Kenneth Lo',
#  'Jose Llado Fernandez-Urrutia',
# ...

# %%
worth_tags=driver.find_elements_by_xpath('//div [@class="netWorth"]')
len(worth_tags)
# Out:
# 200

# %%
worth_titles=[]
for i in worth_tags:
    worth_titles.append(i.text)
worth_titles
# Out:
# ['$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1 B',
#  '$1.1 B',
#  '$1.1 B',
#  '$1.1 B',
#  '$1.1 B',
#  '$1.1 B',
#  '$1.1 B',
#  '$1.1 B',
# ...

# %%
country_tags=driver.find_elements_by_xpath('//div [@class="countryOfCitizenship"]')
len(country_tags)
# Out:
# 200

# %%
country_titles=[]
for i in country_tags:
    country_titles.append(i.text)
country_titles
# Out:
# ['China',
#  'China',
#  'China',
#  'China',
#  'China',
#  'United States',
#  'Singapore',
#  'China',
#  'Russia',
#  'China',
#  'China',
#  'United States',
#  'United States',
#  'China',
#  'China',
#  'United States',
#  'Turkey',
#  'Russia',
#  'Thailand',
#  'Taiwan',
#  'China',
#  'Thailand',
#  'United States',
#  'Australia',
#  'United States',
#  'Italy',
#  'Italy',
#  'Russia',
#  'United States',
#  'South Korea',
#  'Australia',
#  'United States',
#  'Peru',
#  'Canada',
#  'Brazil',
#  'United States',
#  'Mexico',
#  'United States',
#  'Russia',
#  'India',
#  'Canada',
#  'Canada',
#  'India',
#  'Russia',
#  'China',
#  'United Kingdom',
#  'Spain',
#  'China',
#  'China',
#  'Russia',
#  'Russia',
#  'Japan',
#  'United States',
#  'United States',
#  'United States',
#  'India',
#  'India',
#  'Israel',
#  'China',
#  'South Korea',
#  'China',
#  'Iceland',
#  'United Kingdom',
#  'Canada',
#  'China',
#  'Cyprus',
#  'China',
#  'South Korea',
# ...

# %%
source_tags=driver.find_elements_by_xpath('//div [@class="source-column"]')
len(source_tags)
# Out:
# 200

# %%
source_titles=[]
for i in source_tags:
    source_titles.append(i.text)
source_titles
# Out:
# ['Software',
#  'conglomerate',
#  'gold mining',
#  'Fiberglass',
#  'e-commerce',
#  'pharmaceuticals',
#  'Manufacturing',
#  'e-commerce',
#  'pharmacy',
#  'wine',
#  'home appliances',
#  'Citigroup',
#  'Shoes',
#  'optical devices',
#  'artificial turf',
#  'software',
#  'telecom',
#  'investment banking',
#  'telecom, lotteries, insurance',
#  'shoes',
#  'e-commerce',
#  'restaurants',
#  'stock trading',
#  'toys',
#  'real estate',
#  'chemical products',
#  'chemical products',
#  'pulp and paper, diversified',
#  'cloud computing',
#  'retail',
#  'entertainment',
#  'asset management',
#  'processed milk',
#  'toys',
#  'supermarkets',
#  'movies, television',
#  'toll roads',
#  'defense contractor',
#  'fisheries',
#  'real estate',
#  'packaged meats',
#  'pharmaceuticals',
#  'footwear',
#  'fertilizers',
#  'machinery',
#  'textiles',
#  'construction',
#  'software',
#  'Investments',
#  'real estate',
#  'cement',
#  'internet services',
#  'online retailing',
# ...

# %%
rank_tags=driver.find_elements_by_xpath('//div [@class="rank"]')
len(rank_tags)
# Out:
# 200

# %%
rank_titles=[]
for i in rank_tags:
    rank_titles.append(i.text)
rank_titles
# Out:
# ['2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2674.',
#  '2524.',
# ...

# %%
df=pd.DataFrame()
df['name_title']=name_titles
df['rank_title']=rank_titles
df['worth_title']=worth_titles
df['country_title']=country_titles
df['source_title']=source_titles
df
# Out:
#                 name_title rank_title worth_title  country_title  \
# 0          Zhou Wei family      2674.        $1 B          China
# 1           Zhong Naixiong      2674.        $1 B          China
# 2            Zhao Meiguang      2674.        $1 B          China
# 3            Zhang Yuqiang      2674.        $1 B          China
# 4        Daniel Yong Zhang      2674.        $1 B          China
# ..                     ...        ...         ...            ...
# 195          Guo Jianqiang      2524.      $1.1 B          China
# 196            David Golub      2524.      $1.1 B  United States
# 197     Radhe Shyam Goenka      2524.      $1.1 B          India
# 198  Gaston Glock & family      2524.      $1.1 B        Austria
# 199         Anne Gittinger      2524.      $1.1 B  United States
#
#                     source_title
# 0                       Software
# 1                   conglomerate
# 2                    gold mining
# 3                     Fiberglass
# ...

# %%
driver.close()

# %%
# Question 9

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
url="https://www.youtube.com/watch?v=MiQWCh0ahV4"
driver.get(url)

# %%
comment_tags=driver.find_elements_by_xpath('//span[@class="style-scope yt-formatted-string"]')
len(comment_tags)
# Out:
# 514

# %%
comment_titles=[]
for i in comment_tags:
    comment_titles.append(i.text)
comment_titles
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'This was the first time ever that we flew in an A380 plane of emirates in business class. We give you a short overview of the features and services ;)\nFor more info, ',
#  ' \n\nSubscribe for more such videos!\n---------------------------------------------------- \nMY FAVOURITE EQUIPMENT: \n🎥 Studio Camera: ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '2,253',
#  'Comments',
#  'Technical guruji be like- Chlayie Dhruv ko welcome krte h ',
#  'View',
#  '62',
#  'replies',
#  'This video motivates me to work more hard in my academics so that someday even i can board into a plane like this... Thanks to both of you',
#  '!',
#  'View',
#  '34',
#  'replies',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
comment_tags=driver.find_elements_by_xpath('//a[@class="yt-simple-endpoint style-scope yt-formatted-string"]')
len(comment_tags)
# Out:
# 550

# %%
comment_titles=[]
for i in comment_tags:
    comment_titles.append(i.text)
comment_titles
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Dhruv Rathee Vlogs',
#  '@Visit Dubai',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '1 month ago',
#  '',
#  '1 month ago',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '1 month ago',
#  '',
#  '1 month ago',
#  '',
#  '1 month ago',
#  '',
#  '1 month ago',
#  '',
#  '1 month ago',
#  '',
#  '1 month ago',
#  '',
#  '1 month ago',
#  '',
#  '1 month ago',
#  '',
#  '1 month ago',
#  '',
#  '2 weeks ago',
#  '',
#  '1 month ago',
#  '',
#  '1 month ago (edited)',
#  '',
#  '1 month ago',
#  '',
#  '2 weeks ago',
#  '',
#  '1 month ago',
#  '',
#  '3 weeks ago',
#  '',
#  '1 month ago (edited)',
#  '',
#  '1 month ago',
#  '',
#  '1 month ago',
#  '',
#  '1 month ago (edited)',
#  '',
# ...

# %%
upvote_tags=driver.find_elements_by_xpath('//span[@class="style-scope ytd-comment-action-buttons-renderer"]')
len(upvote_tags)
# Out:
# 497

# %%
upvote_titles=[]
for i in upvote_tags:
    upvote_titles.append(i.text)
upvote_titles
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '47',
#  '',
#  '125',
#  '',
#  '14',
#  '',
#  '631',
#  '',
#  '604',
#  '',
#  '110',
#  '',
#  '8',
#  '',
#  '141',
#  '',
#  '',
#  '',
#  '400',
#  '',
#  '221',
#  '',
#  '446',
#  '',
#  '2',
#  '',
#  '60',
#  '',
#  '3',
#  '',
#  '23',
#  '',
#  '154',
#  '',
#  '39',
#  '',
#  '102',
#  '',
#  '22',
#  '',
#  '',
#  '',
#  '56',
#  '',
#  '',
#  '',
#  '69',
#  '',
#  '68',
#  '',
#  '52',
#  '',
#  '',
#  '',
#  '16',
#  '',
#  '1',
#  '',
#  '80',
#  '',
#  '10',
#  '',
#  '22',
#  '',
#  '',
#  '',
#  '65',
#  '',
#  '11',
#  '',
#  '68',
#  '',
#  '45',
#  '',
#  '6',
#  '',
#  '2',
#  '',
#  '',
#  '',
#  '3',
#  '',
#  '8',
#  '',
#  '11',
#  '',
#  '133',
#  '',
#  '6',
#  '',
#  '50',
#  '',
#  '3',
#  '',
#  '34',
#  '',
#  '1',
#  '',
#  '5',
#  '',
#  '4',
#  '',
#  '1',
#  '',
#  '',
#  '',
# ...

# %%
driver.close()

# %%
# Question 10

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
url="https://www.hostelworld.com/"
driver.get(url)

# %%
search_place=driver.find_element_by_xpath("/html/body/div[3]/div/div/div[1]/div[7]/section/div/div[1]/a" )
search_place
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="3c82073b6cf76a99a3400741e9d372b8", element="abdc0253-19e5-47a0-8fad-0197283136a8")>

# %%
search_place.click()

# %%
loc_tags=driver.find_elements_by_xpath('//a[@class="hwta-property-link"]')
len(loc_tags)
# Out:
# 121

# %%
loc_titles=[]
for i in loc_tags:
    loc_titles.append(i.text)
loc_titles
# Out:
# ["St Christopher's Village",
#  'Astor Museum Inn',
#  '',
#  'More...',
#  'Prices from:',
#  'Generator London',
#  '',
#  'More...',
#  'Prices from:',
#  'Safestay London Elephant & Castle',
#  '',
#  'More...',
#  'Prices from:',
#  'Smart Camden Inn Hostel',
#  '',
#  'More...',
#  'Prices from:',
#  'Pickwick Hall',
#  '',
#  'More...',
#  'Prices from:',
#  'No.8 Willesden Hostel London',
#  '',
#  'More...',
#  'Prices from:',
#  'Astor Hyde Park',
#  '',
#  'More...',
#  'Prices from:',
#  'The Walrus Hostel',
#  '',
#  'More...',
#  'Prices from:',
#  'London Backpackers',
#  '',
#  'More...',
#  'Prices from:',
#  'Urbany Hostel London',
#  '',
#  'More...',
#  'Prices from:',
#  'No.8 Seven Sisters',
#  '',
#  'More...',
#  'Prices from:',
#  'Smart Hyde Park View Hostel',
#  '',
#  'More...',
#  'Prices from:',
#  'Smart Russell Square Hostel',
#  '',
#  'More...',
#  'Prices from:',
#  'Prime Backpackers Angel',
#  '',
#  'More...',
#  'Prices from:',
# ...

# %%
distance_tags=driver.find_elements_by_xpath('//div[@class="addressline"]')
len(distance_tags)
# Out:
# 31

# %%
distance_titles=[]
for i in distance_tags:
    distance_titles.append(i.text)
distance_titles
# Out:
# ['1.8km from city centre',
#  '2.2km from city centre - SHOW ON MAP',
#  '3km from city centre - SHOW ON MAP',
#  '1.7km from city centre - SHOW ON MAP',
#  '4.4km from city centre - SHOW ON MAP',
#  '2.3km from city centre - SHOW ON MAP',
#  '10km from city centre - SHOW ON MAP',
#  '4.3km from city centre - SHOW ON MAP',
#  '0.2km from city centre - SHOW ON MAP',
#  '11.9km from city centre - SHOW ON MAP',
#  '5.4km from city centre - SHOW ON MAP',
#  '9km from city centre - SHOW ON MAP',
#  '5km from city centre - SHOW ON MAP',
#  '2.6km from city centre - SHOW ON MAP',
#  '3.6km from city centre - SHOW ON MAP',
#  '1.8km from city centre - SHOW ON MAP',
#  '5.5km from city centre - SHOW ON MAP',
#  '5.9km from city centre - SHOW ON MAP',
#  '1.3km from city centre - SHOW ON MAP',
#  '3.6km from city centre - SHOW ON MAP',
#  '2.1km from city centre - SHOW ON MAP',
#  '5km from city centre - SHOW ON MAP',
#  '6.1km from city centre - SHOW ON MAP',
# ...

# %%
rating_tags=driver.find_elements_by_xpath('//div [@class="fabresult-details-rating"]')
len(rating_tags)
# Out:
# 31

# %%
rating_titles=[]
for i in rating_tags:
    rating_titles.append(i.text)
rating_titles
# Out:
# ['8.2\nFabulous\n11005',
#  '9.0\nSuperb\n8824\nPerfect Location\nSuperb Staff\nExcellent Cleanliness',
#  '7.8\nVery Good\n6815\nWonderful Location\nMarvellous Staff',
#  '8.0\nFabulous\n4061\nWonderful Location',
#  '8.6\nFabulous\n2754\nPerfect Location\nSuperb Staff\nExcellent Cleanliness',
#  '9.0\nSuperb\n2285\nPerfect Location\nSuperb Staff\nExcellent Cleanliness',
#  '7.5\nVery Good\n4666\nMarvellous Staff',
#  '8.4\nFabulous\n11393\nPerfect Location\nMarvellous Staff',
#  '8.2\nFabulous\n3712\nPerfect Location\nMarvellous Staff',
#  '8.3\nFabulous\n4189\nWonderful Location\nMarvellous Staff',
#  '9.6\nSuperb\n201\nPerfect Location\nSuperb Staff\nFantastic Cleanliness',
#  '6.9\nGood\n3700',
#  '7.8\nVery Good\n4525\nWonderful Location\nMarvellous Staff',
#  '6.8\nGood\n9577\nWonderful Location',
#  '9.3\nSuperb\n534\nPerfect Location\nSuperb Staff\nFantastic Cleanliness',
#  '8.2\nFabulous\n3262\nPerfect Location\nMarvellous Staff',
# ...

# %%
price_tags=driver.find_elements_by_xpath('//span [@class="price"]')
len(price_tags)
# Out:
# 61

# %%
price_titles=[]
for i in price_tags:
    price_titles.append(i.text)
price_titles
# Out:
# ['From: INR1305.57',
#  '',
#  'INR1619.32',
#  '',
#  'INR1442.20',
#  '',
#  'INR1416.90',
#  '',
#  'INR1528.23',
#  '',
#  'INR3036.22',
#  '',
#  'INR511.10',
#  '',
#  'INR1720.52',
#  '',
#  'INR2327.77',
#  '',
#  'INR1113.28',
#  '',
#  'INR2115.23',
#  '',
#  'INR500.98',
#  '',
#  'INR1457.39',
#  '',
#  'INR1366.30',
#  '',
#  'INR2226.56',
#  '',
#  'INR1507.99',
#  '',
#  'INR2378.37',
#  '',
#  'INR1315.69',
#  '',
#  'INR1922.94',
#  '',
#  'INR2003.90',
#  '',
#  'INR2293.36',
#  '',
#  'INR1335.94',
#  '',
#  'INR910.87',
#  '',
#  'INR708.45',
#  '',
#  'INR1517.10',
#  '',
#  'INR1518.11',
#  '',
#  'INR708.45',
#  '',
#  'INR1667.90',
#  '',
#  'INR1365.29',
#  '',
#  'INR2216.44',
#  '',
#  'INR1507.99']

# %%
next_btn=driver.find_element_by_xpath("/html/body/div[1]/div[1]/div[2]/div[12]/div[9]/div/div[2]/ul/li[4]" )
next_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="3c82073b6cf76a99a3400741e9d372b8", element="b902c37b-8289-4600-9954-cf5337bfe0f4")>

# %%
next_btn.click()

# %%
loc_tags=driver.find_elements_by_xpath('//a[@class="hwta-property-link"]')
len(loc_tags)
# Out:
# 91

# %%
loc_titles=[]
for i in loc_tags:
    loc_titles.append(i.text)
loc_titles
# Out:
# ["St Christopher's Village",
#  "St Christopher's Camden",
#  'More...',
#  'Prices from:',
#  "St Christopher's Hammersmith",
#  'More...',
#  'Prices from:',
#  'The Dictionary Hostel',
#  'More...',
#  'Prices from:',
#  'Abercorn House',
#  'More...',
#  'Prices from:',
#  "St Christopher's Shepherds Bush",
#  'More...',
#  'Prices from:',
#  'YHA London Central',
#  'More...',
#  'Prices from:',
#  'Selina Camden',
#  'More...',
#  'Prices from:',
#  "St Christopher's Greenwich",
#  'More...',
#  'Prices from:',
#  'International Students House',
#  'More...',
#  'Prices from:',
#  'Astor Kensington',
#  'More...',
#  'Prices from:',
#  'Hostel One Notting Hill',
#  'More...',
#  'Prices from:',
#  'YHA London Earls Court',
#  'More...',
#  'Prices from:',
#  'PubLove @ The Crown, Battersea',
#  'More...',
#  'Prices from:',
#  'PubLove @ The Rose & Crown',
#  'More...',
#  'Prices from:',
#  'Park Villa',
#  'More...',
#  'Prices from:',
#  'Kensal Green Backpackers',
# ...

# %%
distance_tags=driver.find_elements_by_xpath('//div[@class="addressline"]')
len(distance_tags)
# Out:
# 31

# %%
distance_titles=[]
for i in distance_tags:
    distance_titles.append(i.text)
distance_titles
# Out:
# ['1.8km from city centre',
#  '4.3km from city centre - SHOW ON MAP',
#  '7.5km from city centre - SHOW ON MAP',
#  '4.1km from city centre - SHOW ON MAP',
#  '7.3km from city centre - SHOW ON MAP',
#  '7km from city centre - SHOW ON MAP',
#  '2.9km from city centre - SHOW ON MAP',
#  '5.5km from city centre - SHOW ON MAP',
#  '7.6km from city centre - SHOW ON MAP',
#  '3.3km from city centre - SHOW ON MAP',
#  '4.9km from city centre - SHOW ON MAP',
#  '5.5km from city centre - SHOW ON MAP',
#  '5.1km from city centre - SHOW ON MAP',
#  '4.7km from city centre - SHOW ON MAP',
#  '1.6km from city centre - SHOW ON MAP',
#  '6.3km from city centre - SHOW ON MAP',
#  '8.2km from city centre - SHOW ON MAP',
#  '5km from city centre - SHOW ON MAP',
#  '4.3km from city centre - SHOW ON MAP',
#  '3.4km from city centre - SHOW ON MAP',
#  '5.5km from city centre - SHOW ON MAP',
#  '6.9km from city centre - SHOW ON MAP',
#  '1.9km from city centre - SHOW ON MAP',
# ...

# %%
rating_tags=driver.find_elements_by_xpath('//div [@class="fabresult-details-rating"]')
len(rating_tags)
# Out:
# 30

# %%
rating_titles=[]
for i in rating_tags:
    rating_titles.append(i.text)
rating_titles
# Out:
# ['8.2\nFabulous\n11005',
#  '7.4\nVery Good\n3738\nWonderful Location',
#  '8.0\nFabulous\n3977\nWonderful Location\nMarvellous Staff',
#  '7.4\nVery Good\n34\nWonderful Location',
#  '7.0\nVery Good\n3679\nWonderful Location',
#  '7.5\nVery Good\n647\nWonderful Location\nMarvellous Staff',
#  '9.0\nSuperb\n4709\nPerfect Location\nSuperb Staff\nFantastic Cleanliness',
#  '9.2\nSuperb\n16\nPerfect Location\nSuperb Staff\nFantastic Cleanliness',
#  '7.3\nVery Good\n3156',
#  '9.2\nSuperb\n927\nPerfect Location\nSuperb Staff\nExcellent Cleanliness',
#  '7.5\nVery Good\n6345\nWonderful Location\nMarvellous Staff',
#  '7.8\nVery Good\n1317\nWonderful Location\nMarvellous Staff',
#  '9.6\nSuperb\n1386\nPerfect Location\nSuperb Staff\nFantastic Cleanliness',
#  '7.9\nVery Good\n228\nWonderful Location\nMarvellous Staff',
#  '7.9\nVery Good\n111\nWonderful Location\nMarvellous Staff',
#  '8.3\nFabulous\n855\nPerfect Location\nMarvellous Staff',
#  '6.1\nGood\n3613',
# ...

# %%
price_tags=driver.find_elements_by_xpath('//span [@class="price"]')
len(price_tags)
# Out:
# 31

# %%
price_titles=[]
for i in price_tags:
    price_titles.append(i.text)
price_titles
# Out:
# ['From: INR1305.57',
#  'INR1669.92',
#  'INR1103.16',
#  'INR1813.63',
#  'INR1492.81',
#  'INR1204.37',
#  'INR1798.45',
#  'INR2845.95',
#  'INR1103.16',
#  'INR1619.32',
#  'INR1821.73',
#  'INR1761.01',
#  'INR1876.38',
#  'INR1162.87',
#  'INR1518.11',
#  'INR2530.18',
#  'INR1113.28',
#  'INR1619.32',
#  'INR1264.08',
#  'INR1668.91',
#  'INR2024.15',
#  'INR1294.44',
#  'INR2251.86',
#  'INR2361.17',
#  'INR2699.20',
#  'INR708.45',
#  'INR2530.18',
#  'INR3137.43',
#  'INR2024.15',
#  'INR4048.29',
#  'INR3694.07']

# %%
next_btn=driver.find_element_by_xpath("/html/body/div[1]/div[1]/div[2]/div[12]/div[9]/div/div[2]/ul/li[5]" )
next_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="3c82073b6cf76a99a3400741e9d372b8", element="5bfeff49-c7f9-4895-bc8e-220c5810ac32")>

# %%
next_btn.click()

# %%
# And hence the next button continues to get to third page and data is scraped.

# %%
driver.close()
